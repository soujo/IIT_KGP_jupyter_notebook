# %%
import numpy as np
from matplotlib import pyplot as plt

sampling_freq=1500
fundamental_freq = 50

t = np.arange(0, 0.1, 1/sampling_freq)

x = np.sin(2 * np.pi * fundamental_freq * t) + (1/3) * np.sin(3 * 2 * np.pi * fundamental_freq * t)
x_discrete = np.sin(2 * np.pi * (fundamental_freq/sampling_freq) * n) + (1/3) * np.sin(3 * 2 * np.pi * (fundamental_freq/sampling_freq) * n)

# Plot the signal
plt.figure(figsize=(10, 4))
plt.plot(t, x)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

sampling_freq=1500
fundamental_freq = 50
t = np.arange(0, 0.1, 1/sampling_freq)

x_discrete = np.sin(2 * np.pi * (fundamental_freq/sampling_freq) * n) + (1/3) * np.sin(3 * 2 * np.pi * (fundamental_freq/sampling_freq) * n)

def fouriertransform(inputsignal,N):
    X=np.zeros(N,dtype=complex)
    for k in range(0,N-1):
        for n in range(0,N-1):
            X[k] = inputsignal[n] * np.exp(-2j * np.pi * k * n / N)
    return X

X=fouriertransform(x_discrete,8)

plt.figure(figsize = (8, 6))
plt.stem(freq, abs(X))
plt.xlabel('Freq')
plt.ylabel('Amplitude')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 fundamental_freq = 50
#       6 t = np.arange(0, 0.1, 1/sampling_freq)
# ----> 8 x_discrete = np.sin(2 * np.pi * (fundamental_freq/sampling_freq) * n) + (1/3) * np.sin(3 * 2 * np.pi * (fundamental_freq/sampling_freq) * n)
#      10 def fouriertransform(inputsignal,N):
#      11     X=np.zeros(N,dtype=complex)
#
# NameError: name 'n' is not defined
