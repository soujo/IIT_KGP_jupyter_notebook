# %%
from PIL import Image
import numpy as np
import os
from scipy.fftpack import idct 
from scipy.fftpack import dct 
import matplotlib.pyplot as plt

# %%
img = Image.open("/home/soujanya/Downloads/standard_test_images/cameraman.tif")
img = img.convert('L') 
img_array = np.array(img)

section_size = 8
num_sections = (img_array.shape[0] // section_size) * (img_array.shape[1] // section_size)


output_dir = "sections"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)


section_number = 1
sections = []
for i in range(0, img_array.shape[0], section_size):
    for j in range(0, img_array.shape[1], section_size):
        section = img_array[i:i+section_size, j:j+section_size]
        sections.append(section)
        
        Image.fromarray(section).save(os.path.join(output_dir, f"section_{section_number}.tiff"))
        section_number += 1

print(f"Total sections: {len(sections)}")
# Out:
# Total sections: 4096

# %%
import os
from PIL import Image
import numpy as np
from scipy.fftpack import dct

# Define the directory containing the images and the directory to save DCT results
input_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/sections/"
output_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/dct_results/"

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Loop through all the images in the directory
for filename in os.listdir(input_dir):
    if filename.endswith(".tiff"):
        # Extract the section ID from the filename (assuming it's part of the filename)
        section_id = os.path.splitext(filename)[0]  # Extracts 'section_1' from 'section_1.tiff'
        
        # Load the image
        image_path = os.path.join(input_dir, filename)
        section_img = Image.open(image_path)
        
        # Convert image to numpy array
        img_array = np.array(section_img)
        
        # Perform 2D DCT on the image array
        dct_array = dct(dct(img_array.T, norm='ortho').T, norm='ortho')
        
        # Save the DCT array as a .npy file with the section ID in the filename
        output_path = os.path.join(output_dir, f"{section_id}_dct.npy")
        np.save(output_path, dct_array)

        print(f"Processed and saved DCT for {filename} with ID {section_id}")

print("All images have been processed.")
# Out:
# Processed and saved DCT for section_1.tiff with ID section_1
# Processed and saved DCT for section_2.tiff with ID section_2
# Processed and saved DCT for section_3.tiff with ID section_3
# Processed and saved DCT for section_4.tiff with ID section_4
# Processed and saved DCT for section_5.tiff with ID section_5
# Processed and saved DCT for section_6.tiff with ID section_6
# Processed and saved DCT for section_7.tiff with ID section_7
# Processed and saved DCT for section_8.tiff with ID section_8
# Processed and saved DCT for section_9.tiff with ID section_9
# Processed and saved DCT for section_10.tiff with ID section_10
# Processed and saved DCT for section_11.tiff with ID section_11
# Processed and saved DCT for section_12.tiff with ID section_12
# Processed and saved DCT for section_13.tiff with ID section_13
# Processed and saved DCT for section_14.tiff with ID section_14
# Processed and saved DCT for section_15.tiff with ID section_15
# Processed and saved DCT for section_16.tiff with ID section_16
# Processed and saved DCT for section_17.tiff with ID section_17
# Processed and saved DCT for section_18.tiff with ID section_18
# Processed and saved DCT for section_19.tiff with ID section_19
# Processed and saved DCT for section_20.tiff with ID section_20
# Processed and saved DCT for section_21.tiff with ID section_21
# Processed and saved DCT for section_22.tiff with ID section_22
# Processed and saved DCT for section_23.tiff with ID section_23
# Processed and saved DCT for section_24.tiff with ID section_24
# Processed and saved DCT for section_25.tiff with ID section_25
# Processed and saved DCT for section_26.tiff with ID section_26
# Processed and saved DCT for section_27.tiff with ID section_27
# Processed and saved DCT for section_28.tiff with ID section_28
# Processed and saved DCT for section_29.tiff with ID section_29
# Processed and saved DCT for section_30.tiff with ID section_30
# Processed and saved DCT for section_31.tiff with ID section_31
# Processed and saved DCT for section_32.tiff with ID section_32
# Processed and saved DCT for section_33.tiff with ID section_33
# Processed and saved DCT for section_34.tiff with ID section_34
# Processed and saved DCT for section_35.tiff with ID section_35
# Processed and saved DCT for section_36.tiff with ID section_36
# Processed and saved DCT for section_37.tiff with ID section_37
# Processed and saved DCT for section_38.tiff with ID section_38
# Processed and saved DCT for section_39.tiff with ID section_39
# Processed and saved DCT for section_40.tiff with ID section_40
# Processed and saved DCT for section_41.tiff with ID section_41
# Processed and saved DCT for section_42.tiff with ID section_42
# Processed and saved DCT for section_43.tiff with ID section_43
# Processed and saved DCT for section_44.tiff with ID section_44
# Processed and saved DCT for section_45.tiff with ID section_45
# Processed and saved DCT for section_46.tiff with ID section_46
# Processed and saved DCT for section_47.tiff with ID section_47
# Processed and saved DCT for section_48.tiff with ID section_48
# Processed and saved DCT for section_49.tiff with ID section_49
# Processed and saved DCT for section_50.tiff with ID section_50
# Processed and saved DCT for section_51.tiff with ID section_51
# Processed and saved DCT for section_52.tiff with ID section_52
# Processed and saved DCT for section_53.tiff with ID section_53
# Processed and saved DCT for section_54.tiff with ID section_54
# Processed and saved DCT for section_55.tiff with ID section_55
# Processed and saved DCT for section_56.tiff with ID section_56
# Processed and saved DCT for section_57.tiff with ID section_57
# Processed and saved DCT for section_58.tiff with ID section_58
# Processed and saved DCT for section_59.tiff with ID section_59
# Processed and saved DCT for section_60.tiff with ID section_60
# Processed and saved DCT for section_61.tiff with ID section_61
# Processed and saved DCT for section_62.tiff with ID section_62
# Processed and saved DCT for section_63.tiff with ID section_63
# Processed and saved DCT for section_64.tiff with ID section_64
# Processed and saved DCT for section_65.tiff with ID section_65
# Processed and saved DCT for section_66.tiff with ID section_66
# Processed and saved DCT for section_67.tiff with ID section_67
# Processed and saved DCT for section_68.tiff with ID section_68
# Processed and saved DCT for section_69.tiff with ID section_69
# Processed and saved DCT for section_70.tiff with ID section_70
# Processed and saved DCT for section_71.tiff with ID section_71
# Processed and saved DCT for section_72.tiff with ID section_72
# Processed and saved DCT for section_73.tiff with ID section_73
# Processed and saved DCT for section_74.tiff with ID section_74
# Processed and saved DCT for section_75.tiff with ID section_75
# Processed and saved DCT for section_76.tiff with ID section_76
# Processed and saved DCT for section_77.tiff with ID section_77
# Processed and saved DCT for section_78.tiff with ID section_78
# Processed and saved DCT for section_79.tiff with ID section_79
# Processed and saved DCT for section_80.tiff with ID section_80
# Processed and saved DCT for section_81.tiff with ID section_81
# Processed and saved DCT for section_82.tiff with ID section_82
# Processed and saved DCT for section_83.tiff with ID section_83
# Processed and saved DCT for section_84.tiff with ID section_84
# Processed and saved DCT for section_85.tiff with ID section_85
# Processed and saved DCT for section_86.tiff with ID section_86
# Processed and saved DCT for section_87.tiff with ID section_87
# Processed and saved DCT for section_88.tiff with ID section_88
# Processed and saved DCT for section_89.tiff with ID section_89
# Processed and saved DCT for section_90.tiff with ID section_90
# Processed and saved DCT for section_91.tiff with ID section_91
# Processed and saved DCT for section_92.tiff with ID section_92
# Processed and saved DCT for section_93.tiff with ID section_93
# Processed and saved DCT for section_94.tiff with ID section_94
# Processed and saved DCT for section_95.tiff with ID section_95
# Processed and saved DCT for section_96.tiff with ID section_96
# Processed and saved DCT for section_97.tiff with ID section_97
# Processed and saved DCT for section_98.tiff with ID section_98
# Processed and saved DCT for section_99.tiff with ID section_99
# Processed and saved DCT for section_100.tiff with ID section_100
# Processed and saved DCT for section_101.tiff with ID section_101
# Processed and saved DCT for section_102.tiff with ID section_102
# Processed and saved DCT for section_103.tiff with ID section_103
# Processed and saved DCT for section_104.tiff with ID section_104
# Processed and saved DCT for section_105.tiff with ID section_105
# Processed and saved DCT for section_106.tiff with ID section_106
# Processed and saved DCT for section_107.tiff with ID section_107
# Processed and saved DCT for section_108.tiff with ID section_108
# Processed and saved DCT for section_109.tiff with ID section_109
# Processed and saved DCT for section_110.tiff with ID section_110
# Processed and saved DCT for section_111.tiff with ID section_111
# Processed and saved DCT for section_112.tiff with ID section_112
# Processed and saved DCT for section_113.tiff with ID section_113
# Processed and saved DCT for section_114.tiff with ID section_114
# Processed and saved DCT for section_115.tiff with ID section_115
# Processed and saved DCT for section_116.tiff with ID section_116
# Processed and saved DCT for section_117.tiff with ID section_117
# Processed and saved DCT for section_118.tiff with ID section_118
# Processed and saved DCT for section_119.tiff with ID section_119
# Processed and saved DCT for section_120.tiff with ID section_120
# Processed and saved DCT for section_121.tiff with ID section_121
# Processed and saved DCT for section_122.tiff with ID section_122
# Processed and saved DCT for section_123.tiff with ID section_123
# Processed and saved DCT for section_124.tiff with ID section_124
# Processed and saved DCT for section_125.tiff with ID section_125
# Processed and saved DCT for section_126.tiff with ID section_126
# Processed and saved DCT for section_127.tiff with ID section_127
# Processed and saved DCT for section_128.tiff with ID section_128
# Processed and saved DCT for section_129.tiff with ID section_129
# Processed and saved DCT for section_130.tiff with ID section_130
# Processed and saved DCT for section_131.tiff with ID section_131
# Processed and saved DCT for section_132.tiff with ID section_132
# Processed and saved DCT for section_133.tiff with ID section_133
# Processed and saved DCT for section_134.tiff with ID section_134
# Processed and saved DCT for section_135.tiff with ID section_135
# Processed and saved DCT for section_136.tiff with ID section_136
# Processed and saved DCT for section_137.tiff with ID section_137
# Processed and saved DCT for section_138.tiff with ID section_138
# Processed and saved DCT for section_139.tiff with ID section_139
# Processed and saved DCT for section_140.tiff with ID section_140
# Processed and saved DCT for section_141.tiff with ID section_141
# Processed and saved DCT for section_142.tiff with ID section_142
# Processed and saved DCT for section_143.tiff with ID section_143
# Processed and saved DCT for section_144.tiff with ID section_144
# Processed and saved DCT for section_145.tiff with ID section_145
# Processed and saved DCT for section_146.tiff with ID section_146
# Processed and saved DCT for section_147.tiff with ID section_147
# Processed and saved DCT for section_148.tiff with ID section_148
# Processed and saved DCT for section_149.tiff with ID section_149
# Processed and saved DCT for section_150.tiff with ID section_150
# Processed and saved DCT for section_151.tiff with ID section_151
# Processed and saved DCT for section_152.tiff with ID section_152
# Processed and saved DCT for section_153.tiff with ID section_153
# Processed and saved DCT for section_154.tiff with ID section_154
# Processed and saved DCT for section_155.tiff with ID section_155
# Processed and saved DCT for section_156.tiff with ID section_156
# Processed and saved DCT for section_157.tiff with ID section_157
# Processed and saved DCT for section_158.tiff with ID section_158
# Processed and saved DCT for section_159.tiff with ID section_159
# Processed and saved DCT for section_160.tiff with ID section_160
# Processed and saved DCT for section_161.tiff with ID section_161
# Processed and saved DCT for section_162.tiff with ID section_162
# Processed and saved DCT for section_163.tiff with ID section_163
# Processed and saved DCT for section_164.tiff with ID section_164
# Processed and saved DCT for section_165.tiff with ID section_165
# Processed and saved DCT for section_166.tiff with ID section_166
# Processed and saved DCT for section_167.tiff with ID section_167
# Processed and saved DCT for section_168.tiff with ID section_168
# Processed and saved DCT for section_169.tiff with ID section_169
# Processed and saved DCT for section_170.tiff with ID section_170
# Processed and saved DCT for section_171.tiff with ID section_171
# Processed and saved DCT for section_172.tiff with ID section_172
# Processed and saved DCT for section_173.tiff with ID section_173
# Processed and saved DCT for section_174.tiff with ID section_174
# Processed and saved DCT for section_175.tiff with ID section_175
# Processed and saved DCT for section_176.tiff with ID section_176
# Processed and saved DCT for section_177.tiff with ID section_177
# Processed and saved DCT for section_178.tiff with ID section_178
# Processed and saved DCT for section_179.tiff with ID section_179
# Processed and saved DCT for section_180.tiff with ID section_180
# Processed and saved DCT for section_181.tiff with ID section_181
# Processed and saved DCT for section_182.tiff with ID section_182
# Processed and saved DCT for section_183.tiff with ID section_183
# Processed and saved DCT for section_184.tiff with ID section_184
# Processed and saved DCT for section_185.tiff with ID section_185
# Processed and saved DCT for section_186.tiff with ID section_186
# Processed and saved DCT for section_187.tiff with ID section_187
# Processed and saved DCT for section_188.tiff with ID section_188
# Processed and saved DCT for section_189.tiff with ID section_189
# Processed and saved DCT for section_190.tiff with ID section_190
# Processed and saved DCT for section_191.tiff with ID section_191
# Processed and saved DCT for section_192.tiff with ID section_192
# Processed and saved DCT for section_193.tiff with ID section_193
# Processed and saved DCT for section_194.tiff with ID section_194
# Processed and saved DCT for section_195.tiff with ID section_195
# Processed and saved DCT for section_196.tiff with ID section_196
# Processed and saved DCT for section_197.tiff with ID section_197
# Processed and saved DCT for section_198.tiff with ID section_198
# Processed and saved DCT for section_199.tiff with ID section_199
# Processed and saved DCT for section_200.tiff with ID section_200
# Processed and saved DCT for section_201.tiff with ID section_201
# Processed and saved DCT for section_202.tiff with ID section_202
# Processed and saved DCT for section_203.tiff with ID section_203
# Processed and saved DCT for section_204.tiff with ID section_204
# Processed and saved DCT for section_205.tiff with ID section_205
# Processed and saved DCT for section_206.tiff with ID section_206
# Processed and saved DCT for section_207.tiff with ID section_207
# Processed and saved DCT for section_208.tiff with ID section_208
# Processed and saved DCT for section_209.tiff with ID section_209
# Processed and saved DCT for section_210.tiff with ID section_210
# Processed and saved DCT for section_211.tiff with ID section_211
# Processed and saved DCT for section_212.tiff with ID section_212
# Processed and saved DCT for section_213.tiff with ID section_213
# Processed and saved DCT for section_214.tiff with ID section_214
# Processed and saved DCT for section_215.tiff with ID section_215
# Processed and saved DCT for section_216.tiff with ID section_216
# Processed and saved DCT for section_217.tiff with ID section_217
# Processed and saved DCT for section_218.tiff with ID section_218
# Processed and saved DCT for section_219.tiff with ID section_219
# Processed and saved DCT for section_220.tiff with ID section_220
# Processed and saved DCT for section_221.tiff with ID section_221
# Processed and saved DCT for section_222.tiff with ID section_222
# Processed and saved DCT for section_223.tiff with ID section_223
# Processed and saved DCT for section_224.tiff with ID section_224
# Processed and saved DCT for section_225.tiff with ID section_225
# Processed and saved DCT for section_226.tiff with ID section_226
# Processed and saved DCT for section_227.tiff with ID section_227
# Processed and saved DCT for section_228.tiff with ID section_228
# Processed and saved DCT for section_229.tiff with ID section_229
# Processed and saved DCT for section_230.tiff with ID section_230
# Processed and saved DCT for section_231.tiff with ID section_231
# Processed and saved DCT for section_232.tiff with ID section_232
# Processed and saved DCT for section_233.tiff with ID section_233
# Processed and saved DCT for section_234.tiff with ID section_234
# Processed and saved DCT for section_235.tiff with ID section_235
# Processed and saved DCT for section_236.tiff with ID section_236
# Processed and saved DCT for section_237.tiff with ID section_237
# Processed and saved DCT for section_238.tiff with ID section_238
# Processed and saved DCT for section_239.tiff with ID section_239
# Processed and saved DCT for section_240.tiff with ID section_240
# Processed and saved DCT for section_241.tiff with ID section_241
# Processed and saved DCT for section_242.tiff with ID section_242
# Processed and saved DCT for section_243.tiff with ID section_243
# Processed and saved DCT for section_244.tiff with ID section_244
# Processed and saved DCT for section_245.tiff with ID section_245
# Processed and saved DCT for section_246.tiff with ID section_246
# Processed and saved DCT for section_247.tiff with ID section_247
# Processed and saved DCT for section_248.tiff with ID section_248
# Processed and saved DCT for section_249.tiff with ID section_249
# Processed and saved DCT for section_250.tiff with ID section_250
# Processed and saved DCT for section_251.tiff with ID section_251
# Processed and saved DCT for section_252.tiff with ID section_252
# Processed and saved DCT for section_253.tiff with ID section_253
# Processed and saved DCT for section_254.tiff with ID section_254
# Processed and saved DCT for section_255.tiff with ID section_255
# Processed and saved DCT for section_256.tiff with ID section_256
# Processed and saved DCT for section_257.tiff with ID section_257
# Processed and saved DCT for section_258.tiff with ID section_258
# Processed and saved DCT for section_259.tiff with ID section_259
# Processed and saved DCT for section_260.tiff with ID section_260
# Processed and saved DCT for section_261.tiff with ID section_261
# Processed and saved DCT for section_262.tiff with ID section_262
# Processed and saved DCT for section_263.tiff with ID section_263
# Processed and saved DCT for section_264.tiff with ID section_264
# Processed and saved DCT for section_265.tiff with ID section_265
# Processed and saved DCT for section_266.tiff with ID section_266
# Processed and saved DCT for section_267.tiff with ID section_267
# Processed and saved DCT for section_268.tiff with ID section_268
# Processed and saved DCT for section_269.tiff with ID section_269
# Processed and saved DCT for section_270.tiff with ID section_270
# Processed and saved DCT for section_271.tiff with ID section_271
# Processed and saved DCT for section_272.tiff with ID section_272
# Processed and saved DCT for section_273.tiff with ID section_273
# Processed and saved DCT for section_274.tiff with ID section_274
# Processed and saved DCT for section_275.tiff with ID section_275
# Processed and saved DCT for section_276.tiff with ID section_276
# Processed and saved DCT for section_277.tiff with ID section_277
# Processed and saved DCT for section_278.tiff with ID section_278
# Processed and saved DCT for section_279.tiff with ID section_279
# Processed and saved DCT for section_280.tiff with ID section_280
# Processed and saved DCT for section_281.tiff with ID section_281
# Processed and saved DCT for section_282.tiff with ID section_282
# Processed and saved DCT for section_283.tiff with ID section_283
# Processed and saved DCT for section_284.tiff with ID section_284
# Processed and saved DCT for section_285.tiff with ID section_285
# Processed and saved DCT for section_286.tiff with ID section_286
# Processed and saved DCT for section_287.tiff with ID section_287
# Processed and saved DCT for section_288.tiff with ID section_288
# Processed and saved DCT for section_289.tiff with ID section_289
# Processed and saved DCT for section_290.tiff with ID section_290
# Processed and saved DCT for section_291.tiff with ID section_291
# Processed and saved DCT for section_292.tiff with ID section_292
# Processed and saved DCT for section_293.tiff with ID section_293
# Processed and saved DCT for section_294.tiff with ID section_294
# Processed and saved DCT for section_295.tiff with ID section_295
# Processed and saved DCT for section_296.tiff with ID section_296
# Processed and saved DCT for section_297.tiff with ID section_297
# Processed and saved DCT for section_298.tiff with ID section_298
# Processed and saved DCT for section_299.tiff with ID section_299
# Processed and saved DCT for section_300.tiff with ID section_300
# Processed and saved DCT for section_301.tiff with ID section_301
# Processed and saved DCT for section_302.tiff with ID section_302
# Processed and saved DCT for section_303.tiff with ID section_303
# Processed and saved DCT for section_304.tiff with ID section_304
# Processed and saved DCT for section_305.tiff with ID section_305
# Processed and saved DCT for section_306.tiff with ID section_306
# Processed and saved DCT for section_307.tiff with ID section_307
# Processed and saved DCT for section_308.tiff with ID section_308
# Processed and saved DCT for section_309.tiff with ID section_309
# Processed and saved DCT for section_310.tiff with ID section_310
# Processed and saved DCT for section_311.tiff with ID section_311
# Processed and saved DCT for section_312.tiff with ID section_312
# Processed and saved DCT for section_313.tiff with ID section_313
# Processed and saved DCT for section_314.tiff with ID section_314
# Processed and saved DCT for section_315.tiff with ID section_315
# Processed and saved DCT for section_316.tiff with ID section_316
# Processed and saved DCT for section_317.tiff with ID section_317
# Processed and saved DCT for section_318.tiff with ID section_318
# Processed and saved DCT for section_319.tiff with ID section_319
# Processed and saved DCT for section_320.tiff with ID section_320
# Processed and saved DCT for section_321.tiff with ID section_321
# Processed and saved DCT for section_322.tiff with ID section_322
# Processed and saved DCT for section_323.tiff with ID section_323
# Processed and saved DCT for section_324.tiff with ID section_324
# Processed and saved DCT for section_325.tiff with ID section_325
# Processed and saved DCT for section_326.tiff with ID section_326
# Processed and saved DCT for section_327.tiff with ID section_327
# Processed and saved DCT for section_328.tiff with ID section_328
# Processed and saved DCT for section_329.tiff with ID section_329
# Processed and saved DCT for section_330.tiff with ID section_330
# Processed and saved DCT for section_331.tiff with ID section_331
# Processed and saved DCT for section_332.tiff with ID section_332
# Processed and saved DCT for section_333.tiff with ID section_333
# Processed and saved DCT for section_334.tiff with ID section_334
# Processed and saved DCT for section_335.tiff with ID section_335
# Processed and saved DCT for section_336.tiff with ID section_336
# Processed and saved DCT for section_337.tiff with ID section_337
# Processed and saved DCT for section_338.tiff with ID section_338
# Processed and saved DCT for section_339.tiff with ID section_339
# Processed and saved DCT for section_340.tiff with ID section_340
# Processed and saved DCT for section_341.tiff with ID section_341
# Processed and saved DCT for section_342.tiff with ID section_342
# Processed and saved DCT for section_343.tiff with ID section_343
# Processed and saved DCT for section_344.tiff with ID section_344
# Processed and saved DCT for section_345.tiff with ID section_345
# Processed and saved DCT for section_346.tiff with ID section_346
# Processed and saved DCT for section_347.tiff with ID section_347
# Processed and saved DCT for section_348.tiff with ID section_348
# Processed and saved DCT for section_349.tiff with ID section_349
# Processed and saved DCT for section_350.tiff with ID section_350
# Processed and saved DCT for section_351.tiff with ID section_351
# Processed and saved DCT for section_352.tiff with ID section_352
# Processed and saved DCT for section_353.tiff with ID section_353
# Processed and saved DCT for section_354.tiff with ID section_354
# Processed and saved DCT for section_355.tiff with ID section_355
# Processed and saved DCT for section_356.tiff with ID section_356
# Processed and saved DCT for section_357.tiff with ID section_357
# Processed and saved DCT for section_358.tiff with ID section_358
# Processed and saved DCT for section_359.tiff with ID section_359
# Processed and saved DCT for section_360.tiff with ID section_360
# Processed and saved DCT for section_361.tiff with ID section_361
# Processed and saved DCT for section_362.tiff with ID section_362
# Processed and saved DCT for section_363.tiff with ID section_363
# Processed and saved DCT for section_364.tiff with ID section_364
# Processed and saved DCT for section_365.tiff with ID section_365
# Processed and saved DCT for section_366.tiff with ID section_366
# Processed and saved DCT for section_367.tiff with ID section_367
# Processed and saved DCT for section_368.tiff with ID section_368
# Processed and saved DCT for section_369.tiff with ID section_369
# Processed and saved DCT for section_370.tiff with ID section_370
# Processed and saved DCT for section_371.tiff with ID section_371
# Processed and saved DCT for section_372.tiff with ID section_372
# Processed and saved DCT for section_373.tiff with ID section_373
# Processed and saved DCT for section_374.tiff with ID section_374
# Processed and saved DCT for section_375.tiff with ID section_375
# Processed and saved DCT for section_376.tiff with ID section_376
# Processed and saved DCT for section_377.tiff with ID section_377
# Processed and saved DCT for section_378.tiff with ID section_378
# Processed and saved DCT for section_379.tiff with ID section_379
# Processed and saved DCT for section_380.tiff with ID section_380
# Processed and saved DCT for section_381.tiff with ID section_381
# Processed and saved DCT for section_382.tiff with ID section_382
# Processed and saved DCT for section_383.tiff with ID section_383
# Processed and saved DCT for section_384.tiff with ID section_384
# Processed and saved DCT for section_385.tiff with ID section_385
# Processed and saved DCT for section_386.tiff with ID section_386
# Processed and saved DCT for section_387.tiff with ID section_387
# Processed and saved DCT for section_388.tiff with ID section_388
# Processed and saved DCT for section_389.tiff with ID section_389
# Processed and saved DCT for section_390.tiff with ID section_390
# Processed and saved DCT for section_391.tiff with ID section_391
# Processed and saved DCT for section_392.tiff with ID section_392
# Processed and saved DCT for section_393.tiff with ID section_393
# Processed and saved DCT for section_394.tiff with ID section_394
# Processed and saved DCT for section_395.tiff with ID section_395
# Processed and saved DCT for section_396.tiff with ID section_396
# Processed and saved DCT for section_397.tiff with ID section_397
# Processed and saved DCT for section_398.tiff with ID section_398
# Processed and saved DCT for section_399.tiff with ID section_399
# Processed and saved DCT for section_400.tiff with ID section_400
# Processed and saved DCT for section_401.tiff with ID section_401
# Processed and saved DCT for section_402.tiff with ID section_402
# Processed and saved DCT for section_403.tiff with ID section_403
# Processed and saved DCT for section_404.tiff with ID section_404
# Processed and saved DCT for section_405.tiff with ID section_405
# Processed and saved DCT for section_406.tiff with ID section_406
# Processed and saved DCT for section_407.tiff with ID section_407
# Processed and saved DCT for section_408.tiff with ID section_408
# Processed and saved DCT for section_409.tiff with ID section_409
# Processed and saved DCT for section_410.tiff with ID section_410
# Processed and saved DCT for section_411.tiff with ID section_411
# Processed and saved DCT for section_412.tiff with ID section_412
# Processed and saved DCT for section_413.tiff with ID section_413
# Processed and saved DCT for section_414.tiff with ID section_414
# Processed and saved DCT for section_415.tiff with ID section_415
# Processed and saved DCT for section_416.tiff with ID section_416
# Processed and saved DCT for section_417.tiff with ID section_417
# Processed and saved DCT for section_418.tiff with ID section_418
# Processed and saved DCT for section_419.tiff with ID section_419
# Processed and saved DCT for section_420.tiff with ID section_420
# Processed and saved DCT for section_421.tiff with ID section_421
# Processed and saved DCT for section_422.tiff with ID section_422
# Processed and saved DCT for section_423.tiff with ID section_423
# Processed and saved DCT for section_424.tiff with ID section_424
# Processed and saved DCT for section_425.tiff with ID section_425
# Processed and saved DCT for section_426.tiff with ID section_426
# Processed and saved DCT for section_427.tiff with ID section_427
# Processed and saved DCT for section_428.tiff with ID section_428
# Processed and saved DCT for section_429.tiff with ID section_429
# Processed and saved DCT for section_430.tiff with ID section_430
# Processed and saved DCT for section_431.tiff with ID section_431
# Processed and saved DCT for section_432.tiff with ID section_432
# Processed and saved DCT for section_433.tiff with ID section_433
# Processed and saved DCT for section_434.tiff with ID section_434
# Processed and saved DCT for section_435.tiff with ID section_435
# Processed and saved DCT for section_436.tiff with ID section_436
# Processed and saved DCT for section_437.tiff with ID section_437
# Processed and saved DCT for section_438.tiff with ID section_438
# Processed and saved DCT for section_439.tiff with ID section_439
# Processed and saved DCT for section_440.tiff with ID section_440
# Processed and saved DCT for section_441.tiff with ID section_441
# Processed and saved DCT for section_442.tiff with ID section_442
# Processed and saved DCT for section_443.tiff with ID section_443
# Processed and saved DCT for section_444.tiff with ID section_444
# Processed and saved DCT for section_445.tiff with ID section_445
# Processed and saved DCT for section_446.tiff with ID section_446
# Processed and saved DCT for section_447.tiff with ID section_447
# Processed and saved DCT for section_448.tiff with ID section_448
# Processed and saved DCT for section_449.tiff with ID section_449
# Processed and saved DCT for section_450.tiff with ID section_450
# Processed and saved DCT for section_451.tiff with ID section_451
# Processed and saved DCT for section_452.tiff with ID section_452
# Processed and saved DCT for section_453.tiff with ID section_453
# Processed and saved DCT for section_454.tiff with ID section_454
# Processed and saved DCT for section_455.tiff with ID section_455
# Processed and saved DCT for section_456.tiff with ID section_456
# Processed and saved DCT for section_457.tiff with ID section_457
# Processed and saved DCT for section_458.tiff with ID section_458
# Processed and saved DCT for section_459.tiff with ID section_459
# Processed and saved DCT for section_460.tiff with ID section_460
# Processed and saved DCT for section_461.tiff with ID section_461
# Processed and saved DCT for section_462.tiff with ID section_462
# Processed and saved DCT for section_463.tiff with ID section_463
# Processed and saved DCT for section_464.tiff with ID section_464
# Processed and saved DCT for section_465.tiff with ID section_465
# Processed and saved DCT for section_466.tiff with ID section_466
# Processed and saved DCT for section_467.tiff with ID section_467
# Processed and saved DCT for section_468.tiff with ID section_468
# Processed and saved DCT for section_469.tiff with ID section_469
# Processed and saved DCT for section_470.tiff with ID section_470
# Processed and saved DCT for section_471.tiff with ID section_471
# Processed and saved DCT for section_472.tiff with ID section_472
# Processed and saved DCT for section_473.tiff with ID section_473
# Processed and saved DCT for section_474.tiff with ID section_474
# Processed and saved DCT for section_475.tiff with ID section_475
# Processed and saved DCT for section_476.tiff with ID section_476
# Processed and saved DCT for section_477.tiff with ID section_477
# Processed and saved DCT for section_478.tiff with ID section_478
# Processed and saved DCT for section_479.tiff with ID section_479
# Processed and saved DCT for section_480.tiff with ID section_480
# Processed and saved DCT for section_481.tiff with ID section_481
# Processed and saved DCT for section_482.tiff with ID section_482
# Processed and saved DCT for section_483.tiff with ID section_483
# Processed and saved DCT for section_484.tiff with ID section_484
# Processed and saved DCT for section_485.tiff with ID section_485
# Processed and saved DCT for section_486.tiff with ID section_486
# Processed and saved DCT for section_487.tiff with ID section_487
# Processed and saved DCT for section_488.tiff with ID section_488
# Processed and saved DCT for section_489.tiff with ID section_489
# Processed and saved DCT for section_490.tiff with ID section_490
# Processed and saved DCT for section_491.tiff with ID section_491
# Processed and saved DCT for section_492.tiff with ID section_492
# Processed and saved DCT for section_493.tiff with ID section_493
# Processed and saved DCT for section_494.tiff with ID section_494
# Processed and saved DCT for section_495.tiff with ID section_495
# Processed and saved DCT for section_496.tiff with ID section_496
# Processed and saved DCT for section_497.tiff with ID section_497
# Processed and saved DCT for section_498.tiff with ID section_498
# Processed and saved DCT for section_499.tiff with ID section_499
# Processed and saved DCT for section_500.tiff with ID section_500
# Processed and saved DCT for section_501.tiff with ID section_501
# Processed and saved DCT for section_502.tiff with ID section_502
# Processed and saved DCT for section_503.tiff with ID section_503
# Processed and saved DCT for section_504.tiff with ID section_504
# Processed and saved DCT for section_505.tiff with ID section_505
# Processed and saved DCT for section_506.tiff with ID section_506
# Processed and saved DCT for section_507.tiff with ID section_507
# Processed and saved DCT for section_508.tiff with ID section_508
# Processed and saved DCT for section_509.tiff with ID section_509
# Processed and saved DCT for section_510.tiff with ID section_510
# Processed and saved DCT for section_511.tiff with ID section_511
# Processed and saved DCT for section_512.tiff with ID section_512
# Processed and saved DCT for section_513.tiff with ID section_513
# Processed and saved DCT for section_514.tiff with ID section_514
# Processed and saved DCT for section_515.tiff with ID section_515
# Processed and saved DCT for section_516.tiff with ID section_516
# Processed and saved DCT for section_517.tiff with ID section_517
# Processed and saved DCT for section_518.tiff with ID section_518
# Processed and saved DCT for section_519.tiff with ID section_519
# Processed and saved DCT for section_520.tiff with ID section_520
# Processed and saved DCT for section_521.tiff with ID section_521
# Processed and saved DCT for section_522.tiff with ID section_522
# Processed and saved DCT for section_523.tiff with ID section_523
# Processed and saved DCT for section_524.tiff with ID section_524
# Processed and saved DCT for section_525.tiff with ID section_525
# Processed and saved DCT for section_526.tiff with ID section_526
# Processed and saved DCT for section_527.tiff with ID section_527
# Processed and saved DCT for section_528.tiff with ID section_528
# Processed and saved DCT for section_529.tiff with ID section_529
# Processed and saved DCT for section_530.tiff with ID section_530
# Processed and saved DCT for section_531.tiff with ID section_531
# Processed and saved DCT for section_532.tiff with ID section_532
# Processed and saved DCT for section_533.tiff with ID section_533
# Processed and saved DCT for section_534.tiff with ID section_534
# Processed and saved DCT for section_535.tiff with ID section_535
# Processed and saved DCT for section_536.tiff with ID section_536
# Processed and saved DCT for section_537.tiff with ID section_537
# Processed and saved DCT for section_538.tiff with ID section_538
# Processed and saved DCT for section_539.tiff with ID section_539
# Processed and saved DCT for section_540.tiff with ID section_540
# Processed and saved DCT for section_541.tiff with ID section_541
# Processed and saved DCT for section_542.tiff with ID section_542
# Processed and saved DCT for section_543.tiff with ID section_543
# Processed and saved DCT for section_544.tiff with ID section_544
# Processed and saved DCT for section_545.tiff with ID section_545
# Processed and saved DCT for section_546.tiff with ID section_546
# Processed and saved DCT for section_547.tiff with ID section_547
# Processed and saved DCT for section_548.tiff with ID section_548
# Processed and saved DCT for section_549.tiff with ID section_549
# Processed and saved DCT for section_550.tiff with ID section_550
# Processed and saved DCT for section_551.tiff with ID section_551
# Processed and saved DCT for section_552.tiff with ID section_552
# Processed and saved DCT for section_553.tiff with ID section_553
# Processed and saved DCT for section_554.tiff with ID section_554
# Processed and saved DCT for section_555.tiff with ID section_555
# Processed and saved DCT for section_556.tiff with ID section_556
# Processed and saved DCT for section_557.tiff with ID section_557
# Processed and saved DCT for section_558.tiff with ID section_558
# Processed and saved DCT for section_559.tiff with ID section_559
# Processed and saved DCT for section_560.tiff with ID section_560
# Processed and saved DCT for section_561.tiff with ID section_561
# Processed and saved DCT for section_562.tiff with ID section_562
# Processed and saved DCT for section_563.tiff with ID section_563
# Processed and saved DCT for section_564.tiff with ID section_564
# Processed and saved DCT for section_565.tiff with ID section_565
# Processed and saved DCT for section_566.tiff with ID section_566
# Processed and saved DCT for section_567.tiff with ID section_567
# Processed and saved DCT for section_568.tiff with ID section_568
# Processed and saved DCT for section_569.tiff with ID section_569
# Processed and saved DCT for section_570.tiff with ID section_570
# Processed and saved DCT for section_571.tiff with ID section_571
# Processed and saved DCT for section_572.tiff with ID section_572
# Processed and saved DCT for section_573.tiff with ID section_573
# Processed and saved DCT for section_574.tiff with ID section_574
# Processed and saved DCT for section_575.tiff with ID section_575
# Processed and saved DCT for section_576.tiff with ID section_576
# Processed and saved DCT for section_577.tiff with ID section_577
# Processed and saved DCT for section_578.tiff with ID section_578
# Processed and saved DCT for section_579.tiff with ID section_579
# Processed and saved DCT for section_580.tiff with ID section_580
# Processed and saved DCT for section_581.tiff with ID section_581
# Processed and saved DCT for section_582.tiff with ID section_582
# Processed and saved DCT for section_583.tiff with ID section_583
# Processed and saved DCT for section_584.tiff with ID section_584
# Processed and saved DCT for section_585.tiff with ID section_585
# Processed and saved DCT for section_586.tiff with ID section_586
# Processed and saved DCT for section_587.tiff with ID section_587
# Processed and saved DCT for section_588.tiff with ID section_588
# Processed and saved DCT for section_589.tiff with ID section_589
# Processed and saved DCT for section_590.tiff with ID section_590
# Processed and saved DCT for section_591.tiff with ID section_591
# Processed and saved DCT for section_592.tiff with ID section_592
# Processed and saved DCT for section_593.tiff with ID section_593
# Processed and saved DCT for section_594.tiff with ID section_594
# Processed and saved DCT for section_595.tiff with ID section_595
# Processed and saved DCT for section_596.tiff with ID section_596
# Processed and saved DCT for section_597.tiff with ID section_597
# Processed and saved DCT for section_598.tiff with ID section_598
# Processed and saved DCT for section_599.tiff with ID section_599
# Processed and saved DCT for section_600.tiff with ID section_600
# Processed and saved DCT for section_601.tiff with ID section_601
# Processed and saved DCT for section_602.tiff with ID section_602
# Processed and saved DCT for section_603.tiff with ID section_603
# Processed and saved DCT for section_604.tiff with ID section_604
# Processed and saved DCT for section_605.tiff with ID section_605
# Processed and saved DCT for section_606.tiff with ID section_606
# Processed and saved DCT for section_607.tiff with ID section_607
# Processed and saved DCT for section_608.tiff with ID section_608
# Processed and saved DCT for section_609.tiff with ID section_609
# Processed and saved DCT for section_610.tiff with ID section_610
# Processed and saved DCT for section_611.tiff with ID section_611
# Processed and saved DCT for section_612.tiff with ID section_612
# Processed and saved DCT for section_613.tiff with ID section_613
# Processed and saved DCT for section_614.tiff with ID section_614
# Processed and saved DCT for section_615.tiff with ID section_615
# Processed and saved DCT for section_616.tiff with ID section_616
# Processed and saved DCT for section_617.tiff with ID section_617
# Processed and saved DCT for section_618.tiff with ID section_618
# Processed and saved DCT for section_619.tiff with ID section_619
# Processed and saved DCT for section_620.tiff with ID section_620
# Processed and saved DCT for section_621.tiff with ID section_621
# Processed and saved DCT for section_622.tiff with ID section_622
# Processed and saved DCT for section_623.tiff with ID section_623
# Processed and saved DCT for section_624.tiff with ID section_624
# Processed and saved DCT for section_625.tiff with ID section_625
# Processed and saved DCT for section_626.tiff with ID section_626
# Processed and saved DCT for section_627.tiff with ID section_627
# Processed and saved DCT for section_628.tiff with ID section_628
# Processed and saved DCT for section_629.tiff with ID section_629
# Processed and saved DCT for section_630.tiff with ID section_630
# Processed and saved DCT for section_631.tiff with ID section_631
# Processed and saved DCT for section_632.tiff with ID section_632
# Processed and saved DCT for section_633.tiff with ID section_633
# Processed and saved DCT for section_634.tiff with ID section_634
# Processed and saved DCT for section_635.tiff with ID section_635
# Processed and saved DCT for section_636.tiff with ID section_636
# Processed and saved DCT for section_637.tiff with ID section_637
# Processed and saved DCT for section_638.tiff with ID section_638
# Processed and saved DCT for section_639.tiff with ID section_639
# Processed and saved DCT for section_640.tiff with ID section_640
# Processed and saved DCT for section_641.tiff with ID section_641
# Processed and saved DCT for section_642.tiff with ID section_642
# Processed and saved DCT for section_643.tiff with ID section_643
# Processed and saved DCT for section_644.tiff with ID section_644
# Processed and saved DCT for section_645.tiff with ID section_645
# Processed and saved DCT for section_646.tiff with ID section_646
# Processed and saved DCT for section_647.tiff with ID section_647
# Processed and saved DCT for section_648.tiff with ID section_648
# Processed and saved DCT for section_649.tiff with ID section_649
# Processed and saved DCT for section_650.tiff with ID section_650
# Processed and saved DCT for section_651.tiff with ID section_651
# Processed and saved DCT for section_652.tiff with ID section_652
# Processed and saved DCT for section_653.tiff with ID section_653
# Processed and saved DCT for section_654.tiff with ID section_654
# Processed and saved DCT for section_655.tiff with ID section_655
# Processed and saved DCT for section_656.tiff with ID section_656
# Processed and saved DCT for section_657.tiff with ID section_657
# Processed and saved DCT for section_658.tiff with ID section_658
# Processed and saved DCT for section_659.tiff with ID section_659
# Processed and saved DCT for section_660.tiff with ID section_660
# Processed and saved DCT for section_661.tiff with ID section_661
# Processed and saved DCT for section_662.tiff with ID section_662
# Processed and saved DCT for section_663.tiff with ID section_663
# Processed and saved DCT for section_664.tiff with ID section_664
# Processed and saved DCT for section_665.tiff with ID section_665
# Processed and saved DCT for section_666.tiff with ID section_666
# Processed and saved DCT for section_667.tiff with ID section_667
# Processed and saved DCT for section_668.tiff with ID section_668
# Processed and saved DCT for section_669.tiff with ID section_669
# Processed and saved DCT for section_670.tiff with ID section_670
# Processed and saved DCT for section_671.tiff with ID section_671
# Processed and saved DCT for section_672.tiff with ID section_672
# Processed and saved DCT for section_673.tiff with ID section_673
# Processed and saved DCT for section_674.tiff with ID section_674
# Processed and saved DCT for section_675.tiff with ID section_675
# Processed and saved DCT for section_676.tiff with ID section_676
# Processed and saved DCT for section_677.tiff with ID section_677
# Processed and saved DCT for section_678.tiff with ID section_678
# Processed and saved DCT for section_679.tiff with ID section_679
# Processed and saved DCT for section_680.tiff with ID section_680
# Processed and saved DCT for section_681.tiff with ID section_681
# Processed and saved DCT for section_682.tiff with ID section_682
# Processed and saved DCT for section_683.tiff with ID section_683
# Processed and saved DCT for section_684.tiff with ID section_684
# Processed and saved DCT for section_685.tiff with ID section_685
# Processed and saved DCT for section_686.tiff with ID section_686
# Processed and saved DCT for section_687.tiff with ID section_687
# Processed and saved DCT for section_688.tiff with ID section_688
# Processed and saved DCT for section_689.tiff with ID section_689
# Processed and saved DCT for section_690.tiff with ID section_690
# Processed and saved DCT for section_691.tiff with ID section_691
# Processed and saved DCT for section_692.tiff with ID section_692
# Processed and saved DCT for section_693.tiff with ID section_693
# Processed and saved DCT for section_694.tiff with ID section_694
# Processed and saved DCT for section_695.tiff with ID section_695
# Processed and saved DCT for section_696.tiff with ID section_696
# Processed and saved DCT for section_697.tiff with ID section_697
# Processed and saved DCT for section_698.tiff with ID section_698
# Processed and saved DCT for section_699.tiff with ID section_699
# Processed and saved DCT for section_700.tiff with ID section_700
# Processed and saved DCT for section_701.tiff with ID section_701
# Processed and saved DCT for section_702.tiff with ID section_702
# Processed and saved DCT for section_703.tiff with ID section_703
# Processed and saved DCT for section_704.tiff with ID section_704
# Processed and saved DCT for section_705.tiff with ID section_705
# Processed and saved DCT for section_706.tiff with ID section_706
# Processed and saved DCT for section_707.tiff with ID section_707
# Processed and saved DCT for section_708.tiff with ID section_708
# Processed and saved DCT for section_709.tiff with ID section_709
# Processed and saved DCT for section_710.tiff with ID section_710
# Processed and saved DCT for section_711.tiff with ID section_711
# Processed and saved DCT for section_712.tiff with ID section_712
# Processed and saved DCT for section_713.tiff with ID section_713
# Processed and saved DCT for section_714.tiff with ID section_714
# Processed and saved DCT for section_715.tiff with ID section_715
# Processed and saved DCT for section_716.tiff with ID section_716
# Processed and saved DCT for section_717.tiff with ID section_717
# Processed and saved DCT for section_718.tiff with ID section_718
# Processed and saved DCT for section_719.tiff with ID section_719
# Processed and saved DCT for section_720.tiff with ID section_720
# Processed and saved DCT for section_721.tiff with ID section_721
# Processed and saved DCT for section_722.tiff with ID section_722
# Processed and saved DCT for section_723.tiff with ID section_723
# Processed and saved DCT for section_724.tiff with ID section_724
# Processed and saved DCT for section_725.tiff with ID section_725
# Processed and saved DCT for section_726.tiff with ID section_726
# Processed and saved DCT for section_727.tiff with ID section_727
# Processed and saved DCT for section_728.tiff with ID section_728
# Processed and saved DCT for section_729.tiff with ID section_729
# Processed and saved DCT for section_730.tiff with ID section_730
# Processed and saved DCT for section_731.tiff with ID section_731
# Processed and saved DCT for section_732.tiff with ID section_732
# Processed and saved DCT for section_733.tiff with ID section_733
# Processed and saved DCT for section_734.tiff with ID section_734
# Processed and saved DCT for section_735.tiff with ID section_735
# Processed and saved DCT for section_736.tiff with ID section_736
# Processed and saved DCT for section_737.tiff with ID section_737
# Processed and saved DCT for section_738.tiff with ID section_738
# Processed and saved DCT for section_739.tiff with ID section_739
# Processed and saved DCT for section_740.tiff with ID section_740
# Processed and saved DCT for section_741.tiff with ID section_741
# ...
# Processed and saved DCT for section_3859.tiff with ID section_3859
# Processed and saved DCT for section_3860.tiff with ID section_3860
# Processed and saved DCT for section_3861.tiff with ID section_3861
# Processed and saved DCT for section_3862.tiff with ID section_3862
# Processed and saved DCT for section_3863.tiff with ID section_3863
# Processed and saved DCT for section_3864.tiff with ID section_3864
# Processed and saved DCT for section_3865.tiff with ID section_3865
# Processed and saved DCT for section_3866.tiff with ID section_3866
# Processed and saved DCT for section_3867.tiff with ID section_3867
# Processed and saved DCT for section_3868.tiff with ID section_3868
# Processed and saved DCT for section_3869.tiff with ID section_3869
# Processed and saved DCT for section_3870.tiff with ID section_3870
# Processed and saved DCT for section_3871.tiff with ID section_3871
# Processed and saved DCT for section_3872.tiff with ID section_3872
# Processed and saved DCT for section_3873.tiff with ID section_3873
# Processed and saved DCT for section_3874.tiff with ID section_3874
# Processed and saved DCT for section_3875.tiff with ID section_3875
# Processed and saved DCT for section_3876.tiff with ID section_3876
# Processed and saved DCT for section_3877.tiff with ID section_3877
# Processed and saved DCT for section_3878.tiff with ID section_3878
# Processed and saved DCT for section_3879.tiff with ID section_3879
# Processed and saved DCT for section_3880.tiff with ID section_3880
# Processed and saved DCT for section_3881.tiff with ID section_3881
# Processed and saved DCT for section_3882.tiff with ID section_3882
# Processed and saved DCT for section_3883.tiff with ID section_3883
# Processed and saved DCT for section_3884.tiff with ID section_3884
# Processed and saved DCT for section_3885.tiff with ID section_3885
# Processed and saved DCT for section_3886.tiff with ID section_3886
# Processed and saved DCT for section_3887.tiff with ID section_3887
# Processed and saved DCT for section_3888.tiff with ID section_3888
# Processed and saved DCT for section_3889.tiff with ID section_3889
# Processed and saved DCT for section_3890.tiff with ID section_3890
# Processed and saved DCT for section_3891.tiff with ID section_3891
# Processed and saved DCT for section_3892.tiff with ID section_3892
# Processed and saved DCT for section_3893.tiff with ID section_3893
# Processed and saved DCT for section_3894.tiff with ID section_3894
# Processed and saved DCT for section_3895.tiff with ID section_3895
# Processed and saved DCT for section_3896.tiff with ID section_3896
# Processed and saved DCT for section_3897.tiff with ID section_3897
# Processed and saved DCT for section_3898.tiff with ID section_3898
# Processed and saved DCT for section_3899.tiff with ID section_3899
# Processed and saved DCT for section_3900.tiff with ID section_3900
# Processed and saved DCT for section_3901.tiff with ID section_3901
# Processed and saved DCT for section_3902.tiff with ID section_3902
# Processed and saved DCT for section_3903.tiff with ID section_3903
# Processed and saved DCT for section_3904.tiff with ID section_3904
# Processed and saved DCT for section_3905.tiff with ID section_3905
# Processed and saved DCT for section_3906.tiff with ID section_3906
# Processed and saved DCT for section_3907.tiff with ID section_3907
# Processed and saved DCT for section_3908.tiff with ID section_3908
# Processed and saved DCT for section_3909.tiff with ID section_3909
# Processed and saved DCT for section_3910.tiff with ID section_3910
# Processed and saved DCT for section_3911.tiff with ID section_3911
# Processed and saved DCT for section_3912.tiff with ID section_3912
# Processed and saved DCT for section_3913.tiff with ID section_3913
# Processed and saved DCT for section_3914.tiff with ID section_3914
# Processed and saved DCT for section_3915.tiff with ID section_3915
# Processed and saved DCT for section_3916.tiff with ID section_3916
# Processed and saved DCT for section_3917.tiff with ID section_3917
# Processed and saved DCT for section_3918.tiff with ID section_3918
# Processed and saved DCT for section_3919.tiff with ID section_3919
# Processed and saved DCT for section_3920.tiff with ID section_3920
# Processed and saved DCT for section_3921.tiff with ID section_3921
# Processed and saved DCT for section_3922.tiff with ID section_3922
# Processed and saved DCT for section_3923.tiff with ID section_3923
# Processed and saved DCT for section_3924.tiff with ID section_3924
# Processed and saved DCT for section_3925.tiff with ID section_3925
# Processed and saved DCT for section_3926.tiff with ID section_3926
# Processed and saved DCT for section_3927.tiff with ID section_3927
# Processed and saved DCT for section_3928.tiff with ID section_3928
# Processed and saved DCT for section_3929.tiff with ID section_3929
# Processed and saved DCT for section_3930.tiff with ID section_3930
# Processed and saved DCT for section_3931.tiff with ID section_3931
# Processed and saved DCT for section_3932.tiff with ID section_3932
# Processed and saved DCT for section_3933.tiff with ID section_3933
# Processed and saved DCT for section_3934.tiff with ID section_3934
# Processed and saved DCT for section_3935.tiff with ID section_3935
# Processed and saved DCT for section_3936.tiff with ID section_3936
# Processed and saved DCT for section_3937.tiff with ID section_3937
# Processed and saved DCT for section_3938.tiff with ID section_3938
# Processed and saved DCT for section_3939.tiff with ID section_3939
# Processed and saved DCT for section_3940.tiff with ID section_3940
# Processed and saved DCT for section_3941.tiff with ID section_3941
# Processed and saved DCT for section_3942.tiff with ID section_3942
# Processed and saved DCT for section_3943.tiff with ID section_3943
# Processed and saved DCT for section_3944.tiff with ID section_3944
# Processed and saved DCT for section_3945.tiff with ID section_3945
# Processed and saved DCT for section_3946.tiff with ID section_3946
# Processed and saved DCT for section_3947.tiff with ID section_3947
# Processed and saved DCT for section_3948.tiff with ID section_3948
# Processed and saved DCT for section_3949.tiff with ID section_3949
# Processed and saved DCT for section_3950.tiff with ID section_3950
# Processed and saved DCT for section_3951.tiff with ID section_3951
# Processed and saved DCT for section_3952.tiff with ID section_3952
# Processed and saved DCT for section_3953.tiff with ID section_3953
# Processed and saved DCT for section_3954.tiff with ID section_3954
# Processed and saved DCT for section_3955.tiff with ID section_3955
# Processed and saved DCT for section_3956.tiff with ID section_3956
# Processed and saved DCT for section_3957.tiff with ID section_3957
# Processed and saved DCT for section_3958.tiff with ID section_3958
# Processed and saved DCT for section_3959.tiff with ID section_3959
# Processed and saved DCT for section_3960.tiff with ID section_3960
# Processed and saved DCT for section_3961.tiff with ID section_3961
# Processed and saved DCT for section_3962.tiff with ID section_3962
# Processed and saved DCT for section_3963.tiff with ID section_3963
# Processed and saved DCT for section_3964.tiff with ID section_3964
# Processed and saved DCT for section_3965.tiff with ID section_3965
# Processed and saved DCT for section_3966.tiff with ID section_3966
# Processed and saved DCT for section_3967.tiff with ID section_3967
# Processed and saved DCT for section_3968.tiff with ID section_3968
# Processed and saved DCT for section_3969.tiff with ID section_3969
# Processed and saved DCT for section_3970.tiff with ID section_3970
# Processed and saved DCT for section_3971.tiff with ID section_3971
# Processed and saved DCT for section_3972.tiff with ID section_3972
# Processed and saved DCT for section_3973.tiff with ID section_3973
# Processed and saved DCT for section_3974.tiff with ID section_3974
# Processed and saved DCT for section_3975.tiff with ID section_3975
# Processed and saved DCT for section_3976.tiff with ID section_3976
# Processed and saved DCT for section_3977.tiff with ID section_3977
# Processed and saved DCT for section_3978.tiff with ID section_3978
# Processed and saved DCT for section_3979.tiff with ID section_3979
# Processed and saved DCT for section_3980.tiff with ID section_3980
# Processed and saved DCT for section_3981.tiff with ID section_3981
# Processed and saved DCT for section_3982.tiff with ID section_3982
# Processed and saved DCT for section_3983.tiff with ID section_3983
# Processed and saved DCT for section_3984.tiff with ID section_3984
# Processed and saved DCT for section_3985.tiff with ID section_3985
# Processed and saved DCT for section_3986.tiff with ID section_3986
# Processed and saved DCT for section_3987.tiff with ID section_3987
# Processed and saved DCT for section_3988.tiff with ID section_3988
# Processed and saved DCT for section_3989.tiff with ID section_3989
# Processed and saved DCT for section_3990.tiff with ID section_3990
# Processed and saved DCT for section_3991.tiff with ID section_3991
# Processed and saved DCT for section_3992.tiff with ID section_3992
# Processed and saved DCT for section_3993.tiff with ID section_3993
# Processed and saved DCT for section_3994.tiff with ID section_3994
# Processed and saved DCT for section_3995.tiff with ID section_3995
# Processed and saved DCT for section_3996.tiff with ID section_3996
# Processed and saved DCT for section_3997.tiff with ID section_3997
# Processed and saved DCT for section_3998.tiff with ID section_3998
# Processed and saved DCT for section_3999.tiff with ID section_3999
# Processed and saved DCT for section_4000.tiff with ID section_4000
# Processed and saved DCT for section_4001.tiff with ID section_4001
# Processed and saved DCT for section_4002.tiff with ID section_4002
# Processed and saved DCT for section_4003.tiff with ID section_4003
# Processed and saved DCT for section_4004.tiff with ID section_4004
# Processed and saved DCT for section_4005.tiff with ID section_4005
# Processed and saved DCT for section_4006.tiff with ID section_4006
# Processed and saved DCT for section_4007.tiff with ID section_4007
# Processed and saved DCT for section_4008.tiff with ID section_4008
# Processed and saved DCT for section_4009.tiff with ID section_4009
# Processed and saved DCT for section_4010.tiff with ID section_4010
# Processed and saved DCT for section_4011.tiff with ID section_4011
# Processed and saved DCT for section_4012.tiff with ID section_4012
# Processed and saved DCT for section_4013.tiff with ID section_4013
# Processed and saved DCT for section_4014.tiff with ID section_4014
# Processed and saved DCT for section_4015.tiff with ID section_4015
# Processed and saved DCT for section_4016.tiff with ID section_4016
# Processed and saved DCT for section_4017.tiff with ID section_4017
# Processed and saved DCT for section_4018.tiff with ID section_4018
# Processed and saved DCT for section_4019.tiff with ID section_4019
# Processed and saved DCT for section_4020.tiff with ID section_4020
# Processed and saved DCT for section_4021.tiff with ID section_4021
# Processed and saved DCT for section_4022.tiff with ID section_4022
# Processed and saved DCT for section_4023.tiff with ID section_4023
# Processed and saved DCT for section_4024.tiff with ID section_4024
# Processed and saved DCT for section_4025.tiff with ID section_4025
# Processed and saved DCT for section_4026.tiff with ID section_4026
# Processed and saved DCT for section_4027.tiff with ID section_4027
# Processed and saved DCT for section_4028.tiff with ID section_4028
# Processed and saved DCT for section_4029.tiff with ID section_4029
# Processed and saved DCT for section_4030.tiff with ID section_4030
# Processed and saved DCT for section_4031.tiff with ID section_4031
# Processed and saved DCT for section_4032.tiff with ID section_4032
# Processed and saved DCT for section_4033.tiff with ID section_4033
# Processed and saved DCT for section_4034.tiff with ID section_4034
# Processed and saved DCT for section_4035.tiff with ID section_4035
# Processed and saved DCT for section_4036.tiff with ID section_4036
# Processed and saved DCT for section_4037.tiff with ID section_4037
# Processed and saved DCT for section_4038.tiff with ID section_4038
# Processed and saved DCT for section_4039.tiff with ID section_4039
# Processed and saved DCT for section_4040.tiff with ID section_4040
# Processed and saved DCT for section_4041.tiff with ID section_4041
# Processed and saved DCT for section_4042.tiff with ID section_4042
# Processed and saved DCT for section_4043.tiff with ID section_4043
# Processed and saved DCT for section_4044.tiff with ID section_4044
# Processed and saved DCT for section_4045.tiff with ID section_4045
# Processed and saved DCT for section_4046.tiff with ID section_4046
# Processed and saved DCT for section_4047.tiff with ID section_4047
# Processed and saved DCT for section_4048.tiff with ID section_4048
# Processed and saved DCT for section_4049.tiff with ID section_4049
# Processed and saved DCT for section_4050.tiff with ID section_4050
# Processed and saved DCT for section_4051.tiff with ID section_4051
# Processed and saved DCT for section_4052.tiff with ID section_4052
# Processed and saved DCT for section_4053.tiff with ID section_4053
# Processed and saved DCT for section_4054.tiff with ID section_4054
# Processed and saved DCT for section_4055.tiff with ID section_4055
# Processed and saved DCT for section_4056.tiff with ID section_4056
# Processed and saved DCT for section_4057.tiff with ID section_4057
# Processed and saved DCT for section_4058.tiff with ID section_4058
# Processed and saved DCT for section_4059.tiff with ID section_4059
# Processed and saved DCT for section_4060.tiff with ID section_4060
# Processed and saved DCT for section_4061.tiff with ID section_4061
# Processed and saved DCT for section_4062.tiff with ID section_4062
# Processed and saved DCT for section_4063.tiff with ID section_4063
# Processed and saved DCT for section_4064.tiff with ID section_4064
# Processed and saved DCT for section_4065.tiff with ID section_4065
# Processed and saved DCT for section_4066.tiff with ID section_4066
# Processed and saved DCT for section_4067.tiff with ID section_4067
# Processed and saved DCT for section_4068.tiff with ID section_4068
# Processed and saved DCT for section_4069.tiff with ID section_4069
# Processed and saved DCT for section_4070.tiff with ID section_4070
# Processed and saved DCT for section_4071.tiff with ID section_4071
# Processed and saved DCT for section_4072.tiff with ID section_4072
# Processed and saved DCT for section_4073.tiff with ID section_4073
# Processed and saved DCT for section_4074.tiff with ID section_4074
# Processed and saved DCT for section_4075.tiff with ID section_4075
# Processed and saved DCT for section_4076.tiff with ID section_4076
# Processed and saved DCT for section_4077.tiff with ID section_4077
# Processed and saved DCT for section_4078.tiff with ID section_4078
# Processed and saved DCT for section_4079.tiff with ID section_4079
# Processed and saved DCT for section_4080.tiff with ID section_4080
# Processed and saved DCT for section_4081.tiff with ID section_4081
# Processed and saved DCT for section_4082.tiff with ID section_4082
# Processed and saved DCT for section_4083.tiff with ID section_4083
# Processed and saved DCT for section_4084.tiff with ID section_4084
# Processed and saved DCT for section_4085.tiff with ID section_4085
# Processed and saved DCT for section_4086.tiff with ID section_4086
# Processed and saved DCT for section_4087.tiff with ID section_4087
# Processed and saved DCT for section_4088.tiff with ID section_4088
# Processed and saved DCT for section_4089.tiff with ID section_4089
# Processed and saved DCT for section_4090.tiff with ID section_4090
# Processed and saved DCT for section_4091.tiff with ID section_4091
# Processed and saved DCT for section_4092.tiff with ID section_4092
# Processed and saved DCT for section_4093.tiff with ID section_4093
# Processed and saved DCT for section_4094.tiff with ID section_4094
# Processed and saved DCT for section_4095.tiff with ID section_4095
# Processed and saved DCT for section_4096.tiff with ID section_4096
# All images have been processed.

# %%
import os
from PIL import Image
import numpy as np
from scipy.fftpack import dct

def get_zigzag_indices(n):
    indices = np.zeros((n, n), dtype=int)
    index = 0
    for diag in range(2 * n - 1):
        if diag % 2 == 0:
            # Even diagonal - traverse up-right
            r = min(diag, n - 1)
            c = diag - r
            while r >= 0 and c < n:
                indices[r, c] = index
                index += 1
                r -= 1
                c += 1
        else:
            # Odd diagonal - traverse down-left
            c = min(diag, n - 1)
            r = diag - c
            while c >= 0 and r < n:
                indices[r, c] = index
                index += 1
                r += 1
                c -= 1
    return indices

def create_modified_array(original_array, input_index):
    n = original_array.shape[0]
    zigzag_indices = get_zigzag_indices(n)
    max_index = min(input_index, n*n - 1)
   
    new_array = np.zeros_like(original_array)
    for i in range(n):
        for j in range(n):
            if zigzag_indices[i, j] <= max_index:
                new_array[i, j] = original_array[i, j]
            else:
                new_array[i, j] = 0
               
    return new_array

def get_user_input():
    while True:
        try:
            # Ask user for an integer input between 0 and 63
            user_input = int(input("Enter an integer between 0 and 63: "))
            if 0 <= user_input <= 63:
                return user_input
            else:
                print("Invalid input. Please enter a number between 0 and 63.")
        except ValueError:
            print("Invalid input. Please enter a valid integer between 0 and 63.")

# Get user input for the zigzag cutoff
user_input = get_user_input()

# Define the directory containing the images and the directory to save DCT results
input_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/sections/"
dct_output_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/dct_results/"
modified_output_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/modified_results/"

# Create output directories if they don't exist
os.makedirs(dct_output_dir, exist_ok=True)
os.makedirs(modified_output_dir, exist_ok=True)

# Loop through all the images in the directory
for filename in os.listdir(input_dir):
    if filename.endswith(".tiff"):
        # Extract the section ID from the filename (assuming it's part of the filename)
        section_id = os.path.splitext(filename)[0]  # Extracts 'section_1' from 'section_1.tiff'
        
        # Load the image
        image_path = os.path.join(input_dir, filename)
        section_img = Image.open(image_path)
        
        # Convert image to numpy array
        img_array = np.array(section_img)
        
        # Perform 2D DCT on the image array
        dct_array = dct(dct(img_array.T, norm='ortho').T, norm='ortho')
        
        # Apply zigzag modification
        modified_array = create_modified_array(dct_array, user_input)
        
        # Save the original DCT array
        dct_output_path = os.path.join(dct_output_dir, f"{section_id}_dct.npy")
        np.save(dct_output_path, dct_array)

        # Save the modified array in a separate directory
        modified_output_path = os.path.join(modified_output_dir, f"{section_id}_modified.npy")
        np.save(modified_output_path, modified_array)

        print(f"Processed and saved DCT and modified array for {filename} with ID {section_id}")

print("All images have been processed.")
# Out:
# Enter an integer between 0 and 63:  2
# Processed and saved DCT and modified array for section_1.tiff with ID section_1
# Processed and saved DCT and modified array for section_2.tiff with ID section_2
# Processed and saved DCT and modified array for section_3.tiff with ID section_3
# Processed and saved DCT and modified array for section_4.tiff with ID section_4
# Processed and saved DCT and modified array for section_5.tiff with ID section_5
# Processed and saved DCT and modified array for section_6.tiff with ID section_6
# Processed and saved DCT and modified array for section_7.tiff with ID section_7
# Processed and saved DCT and modified array for section_8.tiff with ID section_8
# Processed and saved DCT and modified array for section_9.tiff with ID section_9
# Processed and saved DCT and modified array for section_10.tiff with ID section_10
# Processed and saved DCT and modified array for section_11.tiff with ID section_11
# Processed and saved DCT and modified array for section_12.tiff with ID section_12
# Processed and saved DCT and modified array for section_13.tiff with ID section_13
# Processed and saved DCT and modified array for section_14.tiff with ID section_14
# Processed and saved DCT and modified array for section_15.tiff with ID section_15
# Processed and saved DCT and modified array for section_16.tiff with ID section_16
# Processed and saved DCT and modified array for section_17.tiff with ID section_17
# Processed and saved DCT and modified array for section_18.tiff with ID section_18
# Processed and saved DCT and modified array for section_19.tiff with ID section_19
# Processed and saved DCT and modified array for section_20.tiff with ID section_20
# Processed and saved DCT and modified array for section_21.tiff with ID section_21
# Processed and saved DCT and modified array for section_22.tiff with ID section_22
# Processed and saved DCT and modified array for section_23.tiff with ID section_23
# Processed and saved DCT and modified array for section_24.tiff with ID section_24
# Processed and saved DCT and modified array for section_25.tiff with ID section_25
# Processed and saved DCT and modified array for section_26.tiff with ID section_26
# Processed and saved DCT and modified array for section_27.tiff with ID section_27
# Processed and saved DCT and modified array for section_28.tiff with ID section_28
# Processed and saved DCT and modified array for section_29.tiff with ID section_29
# Processed and saved DCT and modified array for section_30.tiff with ID section_30
# Processed and saved DCT and modified array for section_31.tiff with ID section_31
# Processed and saved DCT and modified array for section_32.tiff with ID section_32
# Processed and saved DCT and modified array for section_33.tiff with ID section_33
# Processed and saved DCT and modified array for section_34.tiff with ID section_34
# Processed and saved DCT and modified array for section_35.tiff with ID section_35
# Processed and saved DCT and modified array for section_36.tiff with ID section_36
# Processed and saved DCT and modified array for section_37.tiff with ID section_37
# Processed and saved DCT and modified array for section_38.tiff with ID section_38
# Processed and saved DCT and modified array for section_39.tiff with ID section_39
# Processed and saved DCT and modified array for section_40.tiff with ID section_40
# Processed and saved DCT and modified array for section_41.tiff with ID section_41
# Processed and saved DCT and modified array for section_42.tiff with ID section_42
# Processed and saved DCT and modified array for section_43.tiff with ID section_43
# Processed and saved DCT and modified array for section_44.tiff with ID section_44
# Processed and saved DCT and modified array for section_45.tiff with ID section_45
# Processed and saved DCT and modified array for section_46.tiff with ID section_46
# Processed and saved DCT and modified array for section_47.tiff with ID section_47
# Processed and saved DCT and modified array for section_48.tiff with ID section_48
# Processed and saved DCT and modified array for section_49.tiff with ID section_49
# Processed and saved DCT and modified array for section_50.tiff with ID section_50
# Processed and saved DCT and modified array for section_51.tiff with ID section_51
# Processed and saved DCT and modified array for section_52.tiff with ID section_52
# Processed and saved DCT and modified array for section_53.tiff with ID section_53
# Processed and saved DCT and modified array for section_54.tiff with ID section_54
# Processed and saved DCT and modified array for section_55.tiff with ID section_55
# Processed and saved DCT and modified array for section_56.tiff with ID section_56
# Processed and saved DCT and modified array for section_57.tiff with ID section_57
# Processed and saved DCT and modified array for section_58.tiff with ID section_58
# Processed and saved DCT and modified array for section_59.tiff with ID section_59
# Processed and saved DCT and modified array for section_60.tiff with ID section_60
# Processed and saved DCT and modified array for section_61.tiff with ID section_61
# Processed and saved DCT and modified array for section_62.tiff with ID section_62
# Processed and saved DCT and modified array for section_63.tiff with ID section_63
# Processed and saved DCT and modified array for section_64.tiff with ID section_64
# Processed and saved DCT and modified array for section_65.tiff with ID section_65
# Processed and saved DCT and modified array for section_66.tiff with ID section_66
# Processed and saved DCT and modified array for section_67.tiff with ID section_67
# Processed and saved DCT and modified array for section_68.tiff with ID section_68
# Processed and saved DCT and modified array for section_69.tiff with ID section_69
# Processed and saved DCT and modified array for section_70.tiff with ID section_70
# Processed and saved DCT and modified array for section_71.tiff with ID section_71
# Processed and saved DCT and modified array for section_72.tiff with ID section_72
# Processed and saved DCT and modified array for section_73.tiff with ID section_73
# Processed and saved DCT and modified array for section_74.tiff with ID section_74
# Processed and saved DCT and modified array for section_75.tiff with ID section_75
# Processed and saved DCT and modified array for section_76.tiff with ID section_76
# Processed and saved DCT and modified array for section_77.tiff with ID section_77
# Processed and saved DCT and modified array for section_78.tiff with ID section_78
# Processed and saved DCT and modified array for section_79.tiff with ID section_79
# Processed and saved DCT and modified array for section_80.tiff with ID section_80
# Processed and saved DCT and modified array for section_81.tiff with ID section_81
# Processed and saved DCT and modified array for section_82.tiff with ID section_82
# Processed and saved DCT and modified array for section_83.tiff with ID section_83
# Processed and saved DCT and modified array for section_84.tiff with ID section_84
# Processed and saved DCT and modified array for section_85.tiff with ID section_85
# Processed and saved DCT and modified array for section_86.tiff with ID section_86
# Processed and saved DCT and modified array for section_87.tiff with ID section_87
# Processed and saved DCT and modified array for section_88.tiff with ID section_88
# Processed and saved DCT and modified array for section_89.tiff with ID section_89
# Processed and saved DCT and modified array for section_90.tiff with ID section_90
# Processed and saved DCT and modified array for section_91.tiff with ID section_91
# Processed and saved DCT and modified array for section_92.tiff with ID section_92
# Processed and saved DCT and modified array for section_93.tiff with ID section_93
# Processed and saved DCT and modified array for section_94.tiff with ID section_94
# Processed and saved DCT and modified array for section_95.tiff with ID section_95
# Processed and saved DCT and modified array for section_96.tiff with ID section_96
# Processed and saved DCT and modified array for section_97.tiff with ID section_97
# Processed and saved DCT and modified array for section_98.tiff with ID section_98
# Processed and saved DCT and modified array for section_99.tiff with ID section_99
# Processed and saved DCT and modified array for section_100.tiff with ID section_100
# Processed and saved DCT and modified array for section_101.tiff with ID section_101
# Processed and saved DCT and modified array for section_102.tiff with ID section_102
# Processed and saved DCT and modified array for section_103.tiff with ID section_103
# Processed and saved DCT and modified array for section_104.tiff with ID section_104
# Processed and saved DCT and modified array for section_105.tiff with ID section_105
# Processed and saved DCT and modified array for section_106.tiff with ID section_106
# Processed and saved DCT and modified array for section_107.tiff with ID section_107
# Processed and saved DCT and modified array for section_108.tiff with ID section_108
# Processed and saved DCT and modified array for section_109.tiff with ID section_109
# Processed and saved DCT and modified array for section_110.tiff with ID section_110
# Processed and saved DCT and modified array for section_111.tiff with ID section_111
# Processed and saved DCT and modified array for section_112.tiff with ID section_112
# Processed and saved DCT and modified array for section_113.tiff with ID section_113
# Processed and saved DCT and modified array for section_114.tiff with ID section_114
# Processed and saved DCT and modified array for section_115.tiff with ID section_115
# Processed and saved DCT and modified array for section_116.tiff with ID section_116
# Processed and saved DCT and modified array for section_117.tiff with ID section_117
# Processed and saved DCT and modified array for section_118.tiff with ID section_118
# Processed and saved DCT and modified array for section_119.tiff with ID section_119
# Processed and saved DCT and modified array for section_120.tiff with ID section_120
# Processed and saved DCT and modified array for section_121.tiff with ID section_121
# Processed and saved DCT and modified array for section_122.tiff with ID section_122
# Processed and saved DCT and modified array for section_123.tiff with ID section_123
# Processed and saved DCT and modified array for section_124.tiff with ID section_124
# Processed and saved DCT and modified array for section_125.tiff with ID section_125
# Processed and saved DCT and modified array for section_126.tiff with ID section_126
# Processed and saved DCT and modified array for section_127.tiff with ID section_127
# Processed and saved DCT and modified array for section_128.tiff with ID section_128
# Processed and saved DCT and modified array for section_129.tiff with ID section_129
# Processed and saved DCT and modified array for section_130.tiff with ID section_130
# Processed and saved DCT and modified array for section_131.tiff with ID section_131
# Processed and saved DCT and modified array for section_132.tiff with ID section_132
# Processed and saved DCT and modified array for section_133.tiff with ID section_133
# Processed and saved DCT and modified array for section_134.tiff with ID section_134
# Processed and saved DCT and modified array for section_135.tiff with ID section_135
# Processed and saved DCT and modified array for section_136.tiff with ID section_136
# Processed and saved DCT and modified array for section_137.tiff with ID section_137
# Processed and saved DCT and modified array for section_138.tiff with ID section_138
# Processed and saved DCT and modified array for section_139.tiff with ID section_139
# Processed and saved DCT and modified array for section_140.tiff with ID section_140
# Processed and saved DCT and modified array for section_141.tiff with ID section_141
# Processed and saved DCT and modified array for section_142.tiff with ID section_142
# Processed and saved DCT and modified array for section_143.tiff with ID section_143
# Processed and saved DCT and modified array for section_144.tiff with ID section_144
# Processed and saved DCT and modified array for section_145.tiff with ID section_145
# Processed and saved DCT and modified array for section_146.tiff with ID section_146
# Processed and saved DCT and modified array for section_147.tiff with ID section_147
# Processed and saved DCT and modified array for section_148.tiff with ID section_148
# Processed and saved DCT and modified array for section_149.tiff with ID section_149
# Processed and saved DCT and modified array for section_150.tiff with ID section_150
# Processed and saved DCT and modified array for section_151.tiff with ID section_151
# Processed and saved DCT and modified array for section_152.tiff with ID section_152
# Processed and saved DCT and modified array for section_153.tiff with ID section_153
# Processed and saved DCT and modified array for section_154.tiff with ID section_154
# Processed and saved DCT and modified array for section_155.tiff with ID section_155
# Processed and saved DCT and modified array for section_156.tiff with ID section_156
# Processed and saved DCT and modified array for section_157.tiff with ID section_157
# Processed and saved DCT and modified array for section_158.tiff with ID section_158
# Processed and saved DCT and modified array for section_159.tiff with ID section_159
# Processed and saved DCT and modified array for section_160.tiff with ID section_160
# Processed and saved DCT and modified array for section_161.tiff with ID section_161
# Processed and saved DCT and modified array for section_162.tiff with ID section_162
# Processed and saved DCT and modified array for section_163.tiff with ID section_163
# Processed and saved DCT and modified array for section_164.tiff with ID section_164
# Processed and saved DCT and modified array for section_165.tiff with ID section_165
# Processed and saved DCT and modified array for section_166.tiff with ID section_166
# Processed and saved DCT and modified array for section_167.tiff with ID section_167
# Processed and saved DCT and modified array for section_168.tiff with ID section_168
# Processed and saved DCT and modified array for section_169.tiff with ID section_169
# Processed and saved DCT and modified array for section_170.tiff with ID section_170
# Processed and saved DCT and modified array for section_171.tiff with ID section_171
# Processed and saved DCT and modified array for section_172.tiff with ID section_172
# Processed and saved DCT and modified array for section_173.tiff with ID section_173
# Processed and saved DCT and modified array for section_174.tiff with ID section_174
# Processed and saved DCT and modified array for section_175.tiff with ID section_175
# Processed and saved DCT and modified array for section_176.tiff with ID section_176
# Processed and saved DCT and modified array for section_177.tiff with ID section_177
# Processed and saved DCT and modified array for section_178.tiff with ID section_178
# Processed and saved DCT and modified array for section_179.tiff with ID section_179
# Processed and saved DCT and modified array for section_180.tiff with ID section_180
# Processed and saved DCT and modified array for section_181.tiff with ID section_181
# Processed and saved DCT and modified array for section_182.tiff with ID section_182
# Processed and saved DCT and modified array for section_183.tiff with ID section_183
# Processed and saved DCT and modified array for section_184.tiff with ID section_184
# Processed and saved DCT and modified array for section_185.tiff with ID section_185
# Processed and saved DCT and modified array for section_186.tiff with ID section_186
# Processed and saved DCT and modified array for section_187.tiff with ID section_187
# Processed and saved DCT and modified array for section_188.tiff with ID section_188
# Processed and saved DCT and modified array for section_189.tiff with ID section_189
# Processed and saved DCT and modified array for section_190.tiff with ID section_190
# Processed and saved DCT and modified array for section_191.tiff with ID section_191
# Processed and saved DCT and modified array for section_192.tiff with ID section_192
# Processed and saved DCT and modified array for section_193.tiff with ID section_193
# Processed and saved DCT and modified array for section_194.tiff with ID section_194
# Processed and saved DCT and modified array for section_195.tiff with ID section_195
# Processed and saved DCT and modified array for section_196.tiff with ID section_196
# Processed and saved DCT and modified array for section_197.tiff with ID section_197
# Processed and saved DCT and modified array for section_198.tiff with ID section_198
# Processed and saved DCT and modified array for section_199.tiff with ID section_199
# Processed and saved DCT and modified array for section_200.tiff with ID section_200
# Processed and saved DCT and modified array for section_201.tiff with ID section_201
# Processed and saved DCT and modified array for section_202.tiff with ID section_202
# Processed and saved DCT and modified array for section_203.tiff with ID section_203
# Processed and saved DCT and modified array for section_204.tiff with ID section_204
# Processed and saved DCT and modified array for section_205.tiff with ID section_205
# Processed and saved DCT and modified array for section_206.tiff with ID section_206
# Processed and saved DCT and modified array for section_207.tiff with ID section_207
# Processed and saved DCT and modified array for section_208.tiff with ID section_208
# Processed and saved DCT and modified array for section_209.tiff with ID section_209
# Processed and saved DCT and modified array for section_210.tiff with ID section_210
# Processed and saved DCT and modified array for section_211.tiff with ID section_211
# Processed and saved DCT and modified array for section_212.tiff with ID section_212
# Processed and saved DCT and modified array for section_213.tiff with ID section_213
# Processed and saved DCT and modified array for section_214.tiff with ID section_214
# Processed and saved DCT and modified array for section_215.tiff with ID section_215
# Processed and saved DCT and modified array for section_216.tiff with ID section_216
# Processed and saved DCT and modified array for section_217.tiff with ID section_217
# Processed and saved DCT and modified array for section_218.tiff with ID section_218
# Processed and saved DCT and modified array for section_219.tiff with ID section_219
# Processed and saved DCT and modified array for section_220.tiff with ID section_220
# Processed and saved DCT and modified array for section_221.tiff with ID section_221
# Processed and saved DCT and modified array for section_222.tiff with ID section_222
# Processed and saved DCT and modified array for section_223.tiff with ID section_223
# Processed and saved DCT and modified array for section_224.tiff with ID section_224
# Processed and saved DCT and modified array for section_225.tiff with ID section_225
# Processed and saved DCT and modified array for section_226.tiff with ID section_226
# Processed and saved DCT and modified array for section_227.tiff with ID section_227
# Processed and saved DCT and modified array for section_228.tiff with ID section_228
# Processed and saved DCT and modified array for section_229.tiff with ID section_229
# Processed and saved DCT and modified array for section_230.tiff with ID section_230
# Processed and saved DCT and modified array for section_231.tiff with ID section_231
# Processed and saved DCT and modified array for section_232.tiff with ID section_232
# Processed and saved DCT and modified array for section_233.tiff with ID section_233
# Processed and saved DCT and modified array for section_234.tiff with ID section_234
# Processed and saved DCT and modified array for section_235.tiff with ID section_235
# Processed and saved DCT and modified array for section_236.tiff with ID section_236
# Processed and saved DCT and modified array for section_237.tiff with ID section_237
# Processed and saved DCT and modified array for section_238.tiff with ID section_238
# Processed and saved DCT and modified array for section_239.tiff with ID section_239
# Processed and saved DCT and modified array for section_240.tiff with ID section_240
# Processed and saved DCT and modified array for section_241.tiff with ID section_241
# Processed and saved DCT and modified array for section_242.tiff with ID section_242
# Processed and saved DCT and modified array for section_243.tiff with ID section_243
# Processed and saved DCT and modified array for section_244.tiff with ID section_244
# Processed and saved DCT and modified array for section_245.tiff with ID section_245
# Processed and saved DCT and modified array for section_246.tiff with ID section_246
# Processed and saved DCT and modified array for section_247.tiff with ID section_247
# Processed and saved DCT and modified array for section_248.tiff with ID section_248
# Processed and saved DCT and modified array for section_249.tiff with ID section_249
# Processed and saved DCT and modified array for section_250.tiff with ID section_250
# Processed and saved DCT and modified array for section_251.tiff with ID section_251
# Processed and saved DCT and modified array for section_252.tiff with ID section_252
# Processed and saved DCT and modified array for section_253.tiff with ID section_253
# Processed and saved DCT and modified array for section_254.tiff with ID section_254
# Processed and saved DCT and modified array for section_255.tiff with ID section_255
# Processed and saved DCT and modified array for section_256.tiff with ID section_256
# Processed and saved DCT and modified array for section_257.tiff with ID section_257
# Processed and saved DCT and modified array for section_258.tiff with ID section_258
# Processed and saved DCT and modified array for section_259.tiff with ID section_259
# Processed and saved DCT and modified array for section_260.tiff with ID section_260
# Processed and saved DCT and modified array for section_261.tiff with ID section_261
# Processed and saved DCT and modified array for section_262.tiff with ID section_262
# Processed and saved DCT and modified array for section_263.tiff with ID section_263
# Processed and saved DCT and modified array for section_264.tiff with ID section_264
# Processed and saved DCT and modified array for section_265.tiff with ID section_265
# Processed and saved DCT and modified array for section_266.tiff with ID section_266
# Processed and saved DCT and modified array for section_267.tiff with ID section_267
# Processed and saved DCT and modified array for section_268.tiff with ID section_268
# Processed and saved DCT and modified array for section_269.tiff with ID section_269
# Processed and saved DCT and modified array for section_270.tiff with ID section_270
# Processed and saved DCT and modified array for section_271.tiff with ID section_271
# Processed and saved DCT and modified array for section_272.tiff with ID section_272
# Processed and saved DCT and modified array for section_273.tiff with ID section_273
# Processed and saved DCT and modified array for section_274.tiff with ID section_274
# Processed and saved DCT and modified array for section_275.tiff with ID section_275
# Processed and saved DCT and modified array for section_276.tiff with ID section_276
# Processed and saved DCT and modified array for section_277.tiff with ID section_277
# Processed and saved DCT and modified array for section_278.tiff with ID section_278
# Processed and saved DCT and modified array for section_279.tiff with ID section_279
# Processed and saved DCT and modified array for section_280.tiff with ID section_280
# Processed and saved DCT and modified array for section_281.tiff with ID section_281
# Processed and saved DCT and modified array for section_282.tiff with ID section_282
# Processed and saved DCT and modified array for section_283.tiff with ID section_283
# Processed and saved DCT and modified array for section_284.tiff with ID section_284
# Processed and saved DCT and modified array for section_285.tiff with ID section_285
# Processed and saved DCT and modified array for section_286.tiff with ID section_286
# Processed and saved DCT and modified array for section_287.tiff with ID section_287
# Processed and saved DCT and modified array for section_288.tiff with ID section_288
# Processed and saved DCT and modified array for section_289.tiff with ID section_289
# Processed and saved DCT and modified array for section_290.tiff with ID section_290
# Processed and saved DCT and modified array for section_291.tiff with ID section_291
# Processed and saved DCT and modified array for section_292.tiff with ID section_292
# Processed and saved DCT and modified array for section_293.tiff with ID section_293
# Processed and saved DCT and modified array for section_294.tiff with ID section_294
# Processed and saved DCT and modified array for section_295.tiff with ID section_295
# Processed and saved DCT and modified array for section_296.tiff with ID section_296
# Processed and saved DCT and modified array for section_297.tiff with ID section_297
# Processed and saved DCT and modified array for section_298.tiff with ID section_298
# Processed and saved DCT and modified array for section_299.tiff with ID section_299
# Processed and saved DCT and modified array for section_300.tiff with ID section_300
# Processed and saved DCT and modified array for section_301.tiff with ID section_301
# Processed and saved DCT and modified array for section_302.tiff with ID section_302
# Processed and saved DCT and modified array for section_303.tiff with ID section_303
# Processed and saved DCT and modified array for section_304.tiff with ID section_304
# Processed and saved DCT and modified array for section_305.tiff with ID section_305
# Processed and saved DCT and modified array for section_306.tiff with ID section_306
# Processed and saved DCT and modified array for section_307.tiff with ID section_307
# Processed and saved DCT and modified array for section_308.tiff with ID section_308
# Processed and saved DCT and modified array for section_309.tiff with ID section_309
# Processed and saved DCT and modified array for section_310.tiff with ID section_310
# Processed and saved DCT and modified array for section_311.tiff with ID section_311
# Processed and saved DCT and modified array for section_312.tiff with ID section_312
# Processed and saved DCT and modified array for section_313.tiff with ID section_313
# Processed and saved DCT and modified array for section_314.tiff with ID section_314
# Processed and saved DCT and modified array for section_315.tiff with ID section_315
# Processed and saved DCT and modified array for section_316.tiff with ID section_316
# Processed and saved DCT and modified array for section_317.tiff with ID section_317
# Processed and saved DCT and modified array for section_318.tiff with ID section_318
# Processed and saved DCT and modified array for section_319.tiff with ID section_319
# Processed and saved DCT and modified array for section_320.tiff with ID section_320
# Processed and saved DCT and modified array for section_321.tiff with ID section_321
# Processed and saved DCT and modified array for section_322.tiff with ID section_322
# Processed and saved DCT and modified array for section_323.tiff with ID section_323
# Processed and saved DCT and modified array for section_324.tiff with ID section_324
# Processed and saved DCT and modified array for section_325.tiff with ID section_325
# Processed and saved DCT and modified array for section_326.tiff with ID section_326
# Processed and saved DCT and modified array for section_327.tiff with ID section_327
# Processed and saved DCT and modified array for section_328.tiff with ID section_328
# Processed and saved DCT and modified array for section_329.tiff with ID section_329
# Processed and saved DCT and modified array for section_330.tiff with ID section_330
# Processed and saved DCT and modified array for section_331.tiff with ID section_331
# Processed and saved DCT and modified array for section_332.tiff with ID section_332
# Processed and saved DCT and modified array for section_333.tiff with ID section_333
# Processed and saved DCT and modified array for section_334.tiff with ID section_334
# Processed and saved DCT and modified array for section_335.tiff with ID section_335
# Processed and saved DCT and modified array for section_336.tiff with ID section_336
# Processed and saved DCT and modified array for section_337.tiff with ID section_337
# Processed and saved DCT and modified array for section_338.tiff with ID section_338
# Processed and saved DCT and modified array for section_339.tiff with ID section_339
# Processed and saved DCT and modified array for section_340.tiff with ID section_340
# Processed and saved DCT and modified array for section_341.tiff with ID section_341
# Processed and saved DCT and modified array for section_342.tiff with ID section_342
# Processed and saved DCT and modified array for section_343.tiff with ID section_343
# Processed and saved DCT and modified array for section_344.tiff with ID section_344
# Processed and saved DCT and modified array for section_345.tiff with ID section_345
# Processed and saved DCT and modified array for section_346.tiff with ID section_346
# Processed and saved DCT and modified array for section_347.tiff with ID section_347
# Processed and saved DCT and modified array for section_348.tiff with ID section_348
# Processed and saved DCT and modified array for section_349.tiff with ID section_349
# Processed and saved DCT and modified array for section_350.tiff with ID section_350
# Processed and saved DCT and modified array for section_351.tiff with ID section_351
# Processed and saved DCT and modified array for section_352.tiff with ID section_352
# Processed and saved DCT and modified array for section_353.tiff with ID section_353
# Processed and saved DCT and modified array for section_354.tiff with ID section_354
# Processed and saved DCT and modified array for section_355.tiff with ID section_355
# Processed and saved DCT and modified array for section_356.tiff with ID section_356
# Processed and saved DCT and modified array for section_357.tiff with ID section_357
# Processed and saved DCT and modified array for section_358.tiff with ID section_358
# Processed and saved DCT and modified array for section_359.tiff with ID section_359
# Processed and saved DCT and modified array for section_360.tiff with ID section_360
# Processed and saved DCT and modified array for section_361.tiff with ID section_361
# Processed and saved DCT and modified array for section_362.tiff with ID section_362
# Processed and saved DCT and modified array for section_363.tiff with ID section_363
# Processed and saved DCT and modified array for section_364.tiff with ID section_364
# Processed and saved DCT and modified array for section_365.tiff with ID section_365
# Processed and saved DCT and modified array for section_366.tiff with ID section_366
# Processed and saved DCT and modified array for section_367.tiff with ID section_367
# Processed and saved DCT and modified array for section_368.tiff with ID section_368
# Processed and saved DCT and modified array for section_369.tiff with ID section_369
# Processed and saved DCT and modified array for section_370.tiff with ID section_370
# Processed and saved DCT and modified array for section_371.tiff with ID section_371
# Processed and saved DCT and modified array for section_372.tiff with ID section_372
# Processed and saved DCT and modified array for section_373.tiff with ID section_373
# Processed and saved DCT and modified array for section_374.tiff with ID section_374
# Processed and saved DCT and modified array for section_375.tiff with ID section_375
# Processed and saved DCT and modified array for section_376.tiff with ID section_376
# Processed and saved DCT and modified array for section_377.tiff with ID section_377
# Processed and saved DCT and modified array for section_378.tiff with ID section_378
# Processed and saved DCT and modified array for section_379.tiff with ID section_379
# Processed and saved DCT and modified array for section_380.tiff with ID section_380
# Processed and saved DCT and modified array for section_381.tiff with ID section_381
# Processed and saved DCT and modified array for section_382.tiff with ID section_382
# Processed and saved DCT and modified array for section_383.tiff with ID section_383
# Processed and saved DCT and modified array for section_384.tiff with ID section_384
# Processed and saved DCT and modified array for section_385.tiff with ID section_385
# Processed and saved DCT and modified array for section_386.tiff with ID section_386
# Processed and saved DCT and modified array for section_387.tiff with ID section_387
# Processed and saved DCT and modified array for section_388.tiff with ID section_388
# Processed and saved DCT and modified array for section_389.tiff with ID section_389
# Processed and saved DCT and modified array for section_390.tiff with ID section_390
# Processed and saved DCT and modified array for section_391.tiff with ID section_391
# Processed and saved DCT and modified array for section_392.tiff with ID section_392
# Processed and saved DCT and modified array for section_393.tiff with ID section_393
# Processed and saved DCT and modified array for section_394.tiff with ID section_394
# Processed and saved DCT and modified array for section_395.tiff with ID section_395
# Processed and saved DCT and modified array for section_396.tiff with ID section_396
# Processed and saved DCT and modified array for section_397.tiff with ID section_397
# Processed and saved DCT and modified array for section_398.tiff with ID section_398
# Processed and saved DCT and modified array for section_399.tiff with ID section_399
# Processed and saved DCT and modified array for section_400.tiff with ID section_400
# Processed and saved DCT and modified array for section_401.tiff with ID section_401
# Processed and saved DCT and modified array for section_402.tiff with ID section_402
# Processed and saved DCT and modified array for section_403.tiff with ID section_403
# Processed and saved DCT and modified array for section_404.tiff with ID section_404
# Processed and saved DCT and modified array for section_405.tiff with ID section_405
# Processed and saved DCT and modified array for section_406.tiff with ID section_406
# Processed and saved DCT and modified array for section_407.tiff with ID section_407
# Processed and saved DCT and modified array for section_408.tiff with ID section_408
# Processed and saved DCT and modified array for section_409.tiff with ID section_409
# Processed and saved DCT and modified array for section_410.tiff with ID section_410
# Processed and saved DCT and modified array for section_411.tiff with ID section_411
# Processed and saved DCT and modified array for section_412.tiff with ID section_412
# Processed and saved DCT and modified array for section_413.tiff with ID section_413
# Processed and saved DCT and modified array for section_414.tiff with ID section_414
# Processed and saved DCT and modified array for section_415.tiff with ID section_415
# Processed and saved DCT and modified array for section_416.tiff with ID section_416
# Processed and saved DCT and modified array for section_417.tiff with ID section_417
# Processed and saved DCT and modified array for section_418.tiff with ID section_418
# Processed and saved DCT and modified array for section_419.tiff with ID section_419
# Processed and saved DCT and modified array for section_420.tiff with ID section_420
# Processed and saved DCT and modified array for section_421.tiff with ID section_421
# Processed and saved DCT and modified array for section_422.tiff with ID section_422
# Processed and saved DCT and modified array for section_423.tiff with ID section_423
# Processed and saved DCT and modified array for section_424.tiff with ID section_424
# Processed and saved DCT and modified array for section_425.tiff with ID section_425
# Processed and saved DCT and modified array for section_426.tiff with ID section_426
# Processed and saved DCT and modified array for section_427.tiff with ID section_427
# Processed and saved DCT and modified array for section_428.tiff with ID section_428
# Processed and saved DCT and modified array for section_429.tiff with ID section_429
# Processed and saved DCT and modified array for section_430.tiff with ID section_430
# Processed and saved DCT and modified array for section_431.tiff with ID section_431
# Processed and saved DCT and modified array for section_432.tiff with ID section_432
# Processed and saved DCT and modified array for section_433.tiff with ID section_433
# Processed and saved DCT and modified array for section_434.tiff with ID section_434
# Processed and saved DCT and modified array for section_435.tiff with ID section_435
# Processed and saved DCT and modified array for section_436.tiff with ID section_436
# Processed and saved DCT and modified array for section_437.tiff with ID section_437
# Processed and saved DCT and modified array for section_438.tiff with ID section_438
# Processed and saved DCT and modified array for section_439.tiff with ID section_439
# Processed and saved DCT and modified array for section_440.tiff with ID section_440
# Processed and saved DCT and modified array for section_441.tiff with ID section_441
# Processed and saved DCT and modified array for section_442.tiff with ID section_442
# Processed and saved DCT and modified array for section_443.tiff with ID section_443
# Processed and saved DCT and modified array for section_444.tiff with ID section_444
# Processed and saved DCT and modified array for section_445.tiff with ID section_445
# Processed and saved DCT and modified array for section_446.tiff with ID section_446
# Processed and saved DCT and modified array for section_447.tiff with ID section_447
# Processed and saved DCT and modified array for section_448.tiff with ID section_448
# Processed and saved DCT and modified array for section_449.tiff with ID section_449
# Processed and saved DCT and modified array for section_450.tiff with ID section_450
# Processed and saved DCT and modified array for section_451.tiff with ID section_451
# Processed and saved DCT and modified array for section_452.tiff with ID section_452
# Processed and saved DCT and modified array for section_453.tiff with ID section_453
# Processed and saved DCT and modified array for section_454.tiff with ID section_454
# Processed and saved DCT and modified array for section_455.tiff with ID section_455
# Processed and saved DCT and modified array for section_456.tiff with ID section_456
# Processed and saved DCT and modified array for section_457.tiff with ID section_457
# Processed and saved DCT and modified array for section_458.tiff with ID section_458
# Processed and saved DCT and modified array for section_459.tiff with ID section_459
# Processed and saved DCT and modified array for section_460.tiff with ID section_460
# Processed and saved DCT and modified array for section_461.tiff with ID section_461
# Processed and saved DCT and modified array for section_462.tiff with ID section_462
# Processed and saved DCT and modified array for section_463.tiff with ID section_463
# Processed and saved DCT and modified array for section_464.tiff with ID section_464
# Processed and saved DCT and modified array for section_465.tiff with ID section_465
# Processed and saved DCT and modified array for section_466.tiff with ID section_466
# Processed and saved DCT and modified array for section_467.tiff with ID section_467
# Processed and saved DCT and modified array for section_468.tiff with ID section_468
# Processed and saved DCT and modified array for section_469.tiff with ID section_469
# Processed and saved DCT and modified array for section_470.tiff with ID section_470
# Processed and saved DCT and modified array for section_471.tiff with ID section_471
# Processed and saved DCT and modified array for section_472.tiff with ID section_472
# Processed and saved DCT and modified array for section_473.tiff with ID section_473
# Processed and saved DCT and modified array for section_474.tiff with ID section_474
# Processed and saved DCT and modified array for section_475.tiff with ID section_475
# Processed and saved DCT and modified array for section_476.tiff with ID section_476
# Processed and saved DCT and modified array for section_477.tiff with ID section_477
# Processed and saved DCT and modified array for section_478.tiff with ID section_478
# Processed and saved DCT and modified array for section_479.tiff with ID section_479
# Processed and saved DCT and modified array for section_480.tiff with ID section_480
# Processed and saved DCT and modified array for section_481.tiff with ID section_481
# Processed and saved DCT and modified array for section_482.tiff with ID section_482
# Processed and saved DCT and modified array for section_483.tiff with ID section_483
# Processed and saved DCT and modified array for section_484.tiff with ID section_484
# Processed and saved DCT and modified array for section_485.tiff with ID section_485
# Processed and saved DCT and modified array for section_486.tiff with ID section_486
# Processed and saved DCT and modified array for section_487.tiff with ID section_487
# Processed and saved DCT and modified array for section_488.tiff with ID section_488
# Processed and saved DCT and modified array for section_489.tiff with ID section_489
# Processed and saved DCT and modified array for section_490.tiff with ID section_490
# Processed and saved DCT and modified array for section_491.tiff with ID section_491
# Processed and saved DCT and modified array for section_492.tiff with ID section_492
# Processed and saved DCT and modified array for section_493.tiff with ID section_493
# Processed and saved DCT and modified array for section_494.tiff with ID section_494
# Processed and saved DCT and modified array for section_495.tiff with ID section_495
# Processed and saved DCT and modified array for section_496.tiff with ID section_496
# Processed and saved DCT and modified array for section_497.tiff with ID section_497
# Processed and saved DCT and modified array for section_498.tiff with ID section_498
# Processed and saved DCT and modified array for section_499.tiff with ID section_499
# Processed and saved DCT and modified array for section_500.tiff with ID section_500
# Processed and saved DCT and modified array for section_501.tiff with ID section_501
# Processed and saved DCT and modified array for section_502.tiff with ID section_502
# Processed and saved DCT and modified array for section_503.tiff with ID section_503
# Processed and saved DCT and modified array for section_504.tiff with ID section_504
# Processed and saved DCT and modified array for section_505.tiff with ID section_505
# Processed and saved DCT and modified array for section_506.tiff with ID section_506
# Processed and saved DCT and modified array for section_507.tiff with ID section_507
# Processed and saved DCT and modified array for section_508.tiff with ID section_508
# Processed and saved DCT and modified array for section_509.tiff with ID section_509
# Processed and saved DCT and modified array for section_510.tiff with ID section_510
# Processed and saved DCT and modified array for section_511.tiff with ID section_511
# Processed and saved DCT and modified array for section_512.tiff with ID section_512
# Processed and saved DCT and modified array for section_513.tiff with ID section_513
# Processed and saved DCT and modified array for section_514.tiff with ID section_514
# Processed and saved DCT and modified array for section_515.tiff with ID section_515
# Processed and saved DCT and modified array for section_516.tiff with ID section_516
# Processed and saved DCT and modified array for section_517.tiff with ID section_517
# Processed and saved DCT and modified array for section_518.tiff with ID section_518
# Processed and saved DCT and modified array for section_519.tiff with ID section_519
# Processed and saved DCT and modified array for section_520.tiff with ID section_520
# Processed and saved DCT and modified array for section_521.tiff with ID section_521
# Processed and saved DCT and modified array for section_522.tiff with ID section_522
# Processed and saved DCT and modified array for section_523.tiff with ID section_523
# Processed and saved DCT and modified array for section_524.tiff with ID section_524
# Processed and saved DCT and modified array for section_525.tiff with ID section_525
# Processed and saved DCT and modified array for section_526.tiff with ID section_526
# Processed and saved DCT and modified array for section_527.tiff with ID section_527
# Processed and saved DCT and modified array for section_528.tiff with ID section_528
# Processed and saved DCT and modified array for section_529.tiff with ID section_529
# Processed and saved DCT and modified array for section_530.tiff with ID section_530
# Processed and saved DCT and modified array for section_531.tiff with ID section_531
# Processed and saved DCT and modified array for section_532.tiff with ID section_532
# Processed and saved DCT and modified array for section_533.tiff with ID section_533
# Processed and saved DCT and modified array for section_534.tiff with ID section_534
# Processed and saved DCT and modified array for section_535.tiff with ID section_535
# Processed and saved DCT and modified array for section_536.tiff with ID section_536
# Processed and saved DCT and modified array for section_537.tiff with ID section_537
# Processed and saved DCT and modified array for section_538.tiff with ID section_538
# Processed and saved DCT and modified array for section_539.tiff with ID section_539
# Processed and saved DCT and modified array for section_540.tiff with ID section_540
# Processed and saved DCT and modified array for section_541.tiff with ID section_541
# Processed and saved DCT and modified array for section_542.tiff with ID section_542
# Processed and saved DCT and modified array for section_543.tiff with ID section_543
# Processed and saved DCT and modified array for section_544.tiff with ID section_544
# Processed and saved DCT and modified array for section_545.tiff with ID section_545
# Processed and saved DCT and modified array for section_546.tiff with ID section_546
# Processed and saved DCT and modified array for section_547.tiff with ID section_547
# Processed and saved DCT and modified array for section_548.tiff with ID section_548
# Processed and saved DCT and modified array for section_549.tiff with ID section_549
# Processed and saved DCT and modified array for section_550.tiff with ID section_550
# Processed and saved DCT and modified array for section_551.tiff with ID section_551
# Processed and saved DCT and modified array for section_552.tiff with ID section_552
# Processed and saved DCT and modified array for section_553.tiff with ID section_553
# Processed and saved DCT and modified array for section_554.tiff with ID section_554
# Processed and saved DCT and modified array for section_555.tiff with ID section_555
# Processed and saved DCT and modified array for section_556.tiff with ID section_556
# Processed and saved DCT and modified array for section_557.tiff with ID section_557
# Processed and saved DCT and modified array for section_558.tiff with ID section_558
# Processed and saved DCT and modified array for section_559.tiff with ID section_559
# Processed and saved DCT and modified array for section_560.tiff with ID section_560
# Processed and saved DCT and modified array for section_561.tiff with ID section_561
# Processed and saved DCT and modified array for section_562.tiff with ID section_562
# Processed and saved DCT and modified array for section_563.tiff with ID section_563
# Processed and saved DCT and modified array for section_564.tiff with ID section_564
# Processed and saved DCT and modified array for section_565.tiff with ID section_565
# Processed and saved DCT and modified array for section_566.tiff with ID section_566
# Processed and saved DCT and modified array for section_567.tiff with ID section_567
# Processed and saved DCT and modified array for section_568.tiff with ID section_568
# Processed and saved DCT and modified array for section_569.tiff with ID section_569
# Processed and saved DCT and modified array for section_570.tiff with ID section_570
# Processed and saved DCT and modified array for section_571.tiff with ID section_571
# Processed and saved DCT and modified array for section_572.tiff with ID section_572
# Processed and saved DCT and modified array for section_573.tiff with ID section_573
# ...
# Processed and saved DCT and modified array for section_3912.tiff with ID section_3912
# Processed and saved DCT and modified array for section_3913.tiff with ID section_3913
# Processed and saved DCT and modified array for section_3914.tiff with ID section_3914
# Processed and saved DCT and modified array for section_3915.tiff with ID section_3915
# Processed and saved DCT and modified array for section_3916.tiff with ID section_3916
# Processed and saved DCT and modified array for section_3917.tiff with ID section_3917
# Processed and saved DCT and modified array for section_3918.tiff with ID section_3918
# Processed and saved DCT and modified array for section_3919.tiff with ID section_3919
# Processed and saved DCT and modified array for section_3920.tiff with ID section_3920
# Processed and saved DCT and modified array for section_3921.tiff with ID section_3921
# Processed and saved DCT and modified array for section_3922.tiff with ID section_3922
# Processed and saved DCT and modified array for section_3923.tiff with ID section_3923
# Processed and saved DCT and modified array for section_3924.tiff with ID section_3924
# Processed and saved DCT and modified array for section_3925.tiff with ID section_3925
# Processed and saved DCT and modified array for section_3926.tiff with ID section_3926
# Processed and saved DCT and modified array for section_3927.tiff with ID section_3927
# Processed and saved DCT and modified array for section_3928.tiff with ID section_3928
# Processed and saved DCT and modified array for section_3929.tiff with ID section_3929
# Processed and saved DCT and modified array for section_3930.tiff with ID section_3930
# Processed and saved DCT and modified array for section_3931.tiff with ID section_3931
# Processed and saved DCT and modified array for section_3932.tiff with ID section_3932
# Processed and saved DCT and modified array for section_3933.tiff with ID section_3933
# Processed and saved DCT and modified array for section_3934.tiff with ID section_3934
# Processed and saved DCT and modified array for section_3935.tiff with ID section_3935
# Processed and saved DCT and modified array for section_3936.tiff with ID section_3936
# Processed and saved DCT and modified array for section_3937.tiff with ID section_3937
# Processed and saved DCT and modified array for section_3938.tiff with ID section_3938
# Processed and saved DCT and modified array for section_3939.tiff with ID section_3939
# Processed and saved DCT and modified array for section_3940.tiff with ID section_3940
# Processed and saved DCT and modified array for section_3941.tiff with ID section_3941
# Processed and saved DCT and modified array for section_3942.tiff with ID section_3942
# Processed and saved DCT and modified array for section_3943.tiff with ID section_3943
# Processed and saved DCT and modified array for section_3944.tiff with ID section_3944
# Processed and saved DCT and modified array for section_3945.tiff with ID section_3945
# Processed and saved DCT and modified array for section_3946.tiff with ID section_3946
# Processed and saved DCT and modified array for section_3947.tiff with ID section_3947
# Processed and saved DCT and modified array for section_3948.tiff with ID section_3948
# Processed and saved DCT and modified array for section_3949.tiff with ID section_3949
# Processed and saved DCT and modified array for section_3950.tiff with ID section_3950
# Processed and saved DCT and modified array for section_3951.tiff with ID section_3951
# Processed and saved DCT and modified array for section_3952.tiff with ID section_3952
# Processed and saved DCT and modified array for section_3953.tiff with ID section_3953
# Processed and saved DCT and modified array for section_3954.tiff with ID section_3954
# Processed and saved DCT and modified array for section_3955.tiff with ID section_3955
# Processed and saved DCT and modified array for section_3956.tiff with ID section_3956
# Processed and saved DCT and modified array for section_3957.tiff with ID section_3957
# Processed and saved DCT and modified array for section_3958.tiff with ID section_3958
# Processed and saved DCT and modified array for section_3959.tiff with ID section_3959
# Processed and saved DCT and modified array for section_3960.tiff with ID section_3960
# Processed and saved DCT and modified array for section_3961.tiff with ID section_3961
# Processed and saved DCT and modified array for section_3962.tiff with ID section_3962
# Processed and saved DCT and modified array for section_3963.tiff with ID section_3963
# Processed and saved DCT and modified array for section_3964.tiff with ID section_3964
# Processed and saved DCT and modified array for section_3965.tiff with ID section_3965
# Processed and saved DCT and modified array for section_3966.tiff with ID section_3966
# Processed and saved DCT and modified array for section_3967.tiff with ID section_3967
# Processed and saved DCT and modified array for section_3968.tiff with ID section_3968
# Processed and saved DCT and modified array for section_3969.tiff with ID section_3969
# Processed and saved DCT and modified array for section_3970.tiff with ID section_3970
# Processed and saved DCT and modified array for section_3971.tiff with ID section_3971
# Processed and saved DCT and modified array for section_3972.tiff with ID section_3972
# Processed and saved DCT and modified array for section_3973.tiff with ID section_3973
# Processed and saved DCT and modified array for section_3974.tiff with ID section_3974
# Processed and saved DCT and modified array for section_3975.tiff with ID section_3975
# Processed and saved DCT and modified array for section_3976.tiff with ID section_3976
# Processed and saved DCT and modified array for section_3977.tiff with ID section_3977
# Processed and saved DCT and modified array for section_3978.tiff with ID section_3978
# Processed and saved DCT and modified array for section_3979.tiff with ID section_3979
# Processed and saved DCT and modified array for section_3980.tiff with ID section_3980
# Processed and saved DCT and modified array for section_3981.tiff with ID section_3981
# Processed and saved DCT and modified array for section_3982.tiff with ID section_3982
# Processed and saved DCT and modified array for section_3983.tiff with ID section_3983
# Processed and saved DCT and modified array for section_3984.tiff with ID section_3984
# Processed and saved DCT and modified array for section_3985.tiff with ID section_3985
# Processed and saved DCT and modified array for section_3986.tiff with ID section_3986
# Processed and saved DCT and modified array for section_3987.tiff with ID section_3987
# Processed and saved DCT and modified array for section_3988.tiff with ID section_3988
# Processed and saved DCT and modified array for section_3989.tiff with ID section_3989
# Processed and saved DCT and modified array for section_3990.tiff with ID section_3990
# Processed and saved DCT and modified array for section_3991.tiff with ID section_3991
# Processed and saved DCT and modified array for section_3992.tiff with ID section_3992
# Processed and saved DCT and modified array for section_3993.tiff with ID section_3993
# Processed and saved DCT and modified array for section_3994.tiff with ID section_3994
# Processed and saved DCT and modified array for section_3995.tiff with ID section_3995
# Processed and saved DCT and modified array for section_3996.tiff with ID section_3996
# Processed and saved DCT and modified array for section_3997.tiff with ID section_3997
# Processed and saved DCT and modified array for section_3998.tiff with ID section_3998
# Processed and saved DCT and modified array for section_3999.tiff with ID section_3999
# Processed and saved DCT and modified array for section_4000.tiff with ID section_4000
# Processed and saved DCT and modified array for section_4001.tiff with ID section_4001
# Processed and saved DCT and modified array for section_4002.tiff with ID section_4002
# Processed and saved DCT and modified array for section_4003.tiff with ID section_4003
# Processed and saved DCT and modified array for section_4004.tiff with ID section_4004
# Processed and saved DCT and modified array for section_4005.tiff with ID section_4005
# Processed and saved DCT and modified array for section_4006.tiff with ID section_4006
# Processed and saved DCT and modified array for section_4007.tiff with ID section_4007
# Processed and saved DCT and modified array for section_4008.tiff with ID section_4008
# Processed and saved DCT and modified array for section_4009.tiff with ID section_4009
# Processed and saved DCT and modified array for section_4010.tiff with ID section_4010
# Processed and saved DCT and modified array for section_4011.tiff with ID section_4011
# Processed and saved DCT and modified array for section_4012.tiff with ID section_4012
# Processed and saved DCT and modified array for section_4013.tiff with ID section_4013
# Processed and saved DCT and modified array for section_4014.tiff with ID section_4014
# Processed and saved DCT and modified array for section_4015.tiff with ID section_4015
# Processed and saved DCT and modified array for section_4016.tiff with ID section_4016
# Processed and saved DCT and modified array for section_4017.tiff with ID section_4017
# Processed and saved DCT and modified array for section_4018.tiff with ID section_4018
# Processed and saved DCT and modified array for section_4019.tiff with ID section_4019
# Processed and saved DCT and modified array for section_4020.tiff with ID section_4020
# Processed and saved DCT and modified array for section_4021.tiff with ID section_4021
# Processed and saved DCT and modified array for section_4022.tiff with ID section_4022
# Processed and saved DCT and modified array for section_4023.tiff with ID section_4023
# Processed and saved DCT and modified array for section_4024.tiff with ID section_4024
# Processed and saved DCT and modified array for section_4025.tiff with ID section_4025
# Processed and saved DCT and modified array for section_4026.tiff with ID section_4026
# Processed and saved DCT and modified array for section_4027.tiff with ID section_4027
# Processed and saved DCT and modified array for section_4028.tiff with ID section_4028
# Processed and saved DCT and modified array for section_4029.tiff with ID section_4029
# Processed and saved DCT and modified array for section_4030.tiff with ID section_4030
# Processed and saved DCT and modified array for section_4031.tiff with ID section_4031
# Processed and saved DCT and modified array for section_4032.tiff with ID section_4032
# Processed and saved DCT and modified array for section_4033.tiff with ID section_4033
# Processed and saved DCT and modified array for section_4034.tiff with ID section_4034
# Processed and saved DCT and modified array for section_4035.tiff with ID section_4035
# Processed and saved DCT and modified array for section_4036.tiff with ID section_4036
# Processed and saved DCT and modified array for section_4037.tiff with ID section_4037
# Processed and saved DCT and modified array for section_4038.tiff with ID section_4038
# Processed and saved DCT and modified array for section_4039.tiff with ID section_4039
# Processed and saved DCT and modified array for section_4040.tiff with ID section_4040
# Processed and saved DCT and modified array for section_4041.tiff with ID section_4041
# Processed and saved DCT and modified array for section_4042.tiff with ID section_4042
# Processed and saved DCT and modified array for section_4043.tiff with ID section_4043
# Processed and saved DCT and modified array for section_4044.tiff with ID section_4044
# Processed and saved DCT and modified array for section_4045.tiff with ID section_4045
# Processed and saved DCT and modified array for section_4046.tiff with ID section_4046
# Processed and saved DCT and modified array for section_4047.tiff with ID section_4047
# Processed and saved DCT and modified array for section_4048.tiff with ID section_4048
# Processed and saved DCT and modified array for section_4049.tiff with ID section_4049
# Processed and saved DCT and modified array for section_4050.tiff with ID section_4050
# Processed and saved DCT and modified array for section_4051.tiff with ID section_4051
# Processed and saved DCT and modified array for section_4052.tiff with ID section_4052
# Processed and saved DCT and modified array for section_4053.tiff with ID section_4053
# Processed and saved DCT and modified array for section_4054.tiff with ID section_4054
# Processed and saved DCT and modified array for section_4055.tiff with ID section_4055
# Processed and saved DCT and modified array for section_4056.tiff with ID section_4056
# Processed and saved DCT and modified array for section_4057.tiff with ID section_4057
# Processed and saved DCT and modified array for section_4058.tiff with ID section_4058
# Processed and saved DCT and modified array for section_4059.tiff with ID section_4059
# Processed and saved DCT and modified array for section_4060.tiff with ID section_4060
# Processed and saved DCT and modified array for section_4061.tiff with ID section_4061
# Processed and saved DCT and modified array for section_4062.tiff with ID section_4062
# Processed and saved DCT and modified array for section_4063.tiff with ID section_4063
# Processed and saved DCT and modified array for section_4064.tiff with ID section_4064
# Processed and saved DCT and modified array for section_4065.tiff with ID section_4065
# Processed and saved DCT and modified array for section_4066.tiff with ID section_4066
# Processed and saved DCT and modified array for section_4067.tiff with ID section_4067
# Processed and saved DCT and modified array for section_4068.tiff with ID section_4068
# Processed and saved DCT and modified array for section_4069.tiff with ID section_4069
# Processed and saved DCT and modified array for section_4070.tiff with ID section_4070
# Processed and saved DCT and modified array for section_4071.tiff with ID section_4071
# Processed and saved DCT and modified array for section_4072.tiff with ID section_4072
# Processed and saved DCT and modified array for section_4073.tiff with ID section_4073
# Processed and saved DCT and modified array for section_4074.tiff with ID section_4074
# Processed and saved DCT and modified array for section_4075.tiff with ID section_4075
# Processed and saved DCT and modified array for section_4076.tiff with ID section_4076
# Processed and saved DCT and modified array for section_4077.tiff with ID section_4077
# Processed and saved DCT and modified array for section_4078.tiff with ID section_4078
# Processed and saved DCT and modified array for section_4079.tiff with ID section_4079
# Processed and saved DCT and modified array for section_4080.tiff with ID section_4080
# Processed and saved DCT and modified array for section_4081.tiff with ID section_4081
# Processed and saved DCT and modified array for section_4082.tiff with ID section_4082
# Processed and saved DCT and modified array for section_4083.tiff with ID section_4083
# Processed and saved DCT and modified array for section_4084.tiff with ID section_4084
# Processed and saved DCT and modified array for section_4085.tiff with ID section_4085
# Processed and saved DCT and modified array for section_4086.tiff with ID section_4086
# Processed and saved DCT and modified array for section_4087.tiff with ID section_4087
# Processed and saved DCT and modified array for section_4088.tiff with ID section_4088
# Processed and saved DCT and modified array for section_4089.tiff with ID section_4089
# Processed and saved DCT and modified array for section_4090.tiff with ID section_4090
# Processed and saved DCT and modified array for section_4091.tiff with ID section_4091
# Processed and saved DCT and modified array for section_4092.tiff with ID section_4092
# Processed and saved DCT and modified array for section_4093.tiff with ID section_4093
# Processed and saved DCT and modified array for section_4094.tiff with ID section_4094
# Processed and saved DCT and modified array for section_4095.tiff with ID section_4095
# Processed and saved DCT and modified array for section_4096.tiff with ID section_4096
# All images have been processed.

# %%
import os
import numpy as np
from scipy.fftpack import idct

# Function to perform 2D IDCT
def idct2(a):
    return idct(idct(a.T, norm='ortho').T, norm='ortho')

# Define the directory containing the modified arrays and the directory to save IDCT results
modified_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/modified_results/"
idct_output_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/idct_results/"

# Create output directory if it doesn't exist
os.makedirs(idct_output_dir, exist_ok=True)

# Loop through all the modified arrays in the directory
for filename in os.listdir(modified_dir):
    if filename.endswith("_modified.npy"):
        # Load the modified array
        modified_array_path = os.path.join(modified_dir, filename)
        modified_array = np.load(modified_array_path)
        
        # Perform the IDCT
        reconstructed_image = idct2(modified_array)
        
        # Ensure the reconstructed image is in the valid range (0-255) and of type uint8
        reconstructed_image = np.clip(reconstructed_image, 0, 255)
        reconstructed_image = reconstructed_image.astype(np.uint8)
        
        # Save the reconstructed image in the IDCT results directory
        idct_output_path = os.path.join(idct_output_dir, filename.replace("_modified.npy", "_idct.npy"))
        np.save(idct_output_path, reconstructed_image)

        print(f"Processed and saved IDCT for {filename}")

print("All modified arrays have been processed.")
# Out:
# Processed and saved IDCT for section_1_modified.npy
# Processed and saved IDCT for section_2_modified.npy
# Processed and saved IDCT for section_3_modified.npy
# Processed and saved IDCT for section_4_modified.npy
# Processed and saved IDCT for section_5_modified.npy
# Processed and saved IDCT for section_6_modified.npy
# Processed and saved IDCT for section_7_modified.npy
# Processed and saved IDCT for section_8_modified.npy
# Processed and saved IDCT for section_9_modified.npy
# Processed and saved IDCT for section_10_modified.npy
# Processed and saved IDCT for section_11_modified.npy
# Processed and saved IDCT for section_12_modified.npy
# Processed and saved IDCT for section_13_modified.npy
# Processed and saved IDCT for section_14_modified.npy
# Processed and saved IDCT for section_15_modified.npy
# Processed and saved IDCT for section_16_modified.npy
# Processed and saved IDCT for section_17_modified.npy
# Processed and saved IDCT for section_18_modified.npy
# Processed and saved IDCT for section_19_modified.npy
# Processed and saved IDCT for section_20_modified.npy
# Processed and saved IDCT for section_21_modified.npy
# Processed and saved IDCT for section_22_modified.npy
# Processed and saved IDCT for section_23_modified.npy
# Processed and saved IDCT for section_24_modified.npy
# Processed and saved IDCT for section_25_modified.npy
# Processed and saved IDCT for section_26_modified.npy
# Processed and saved IDCT for section_27_modified.npy
# Processed and saved IDCT for section_28_modified.npy
# Processed and saved IDCT for section_29_modified.npy
# Processed and saved IDCT for section_30_modified.npy
# Processed and saved IDCT for section_31_modified.npy
# Processed and saved IDCT for section_32_modified.npy
# Processed and saved IDCT for section_33_modified.npy
# Processed and saved IDCT for section_34_modified.npy
# Processed and saved IDCT for section_35_modified.npy
# Processed and saved IDCT for section_36_modified.npy
# Processed and saved IDCT for section_37_modified.npy
# Processed and saved IDCT for section_38_modified.npy
# Processed and saved IDCT for section_39_modified.npy
# Processed and saved IDCT for section_40_modified.npy
# Processed and saved IDCT for section_41_modified.npy
# Processed and saved IDCT for section_42_modified.npy
# Processed and saved IDCT for section_43_modified.npy
# Processed and saved IDCT for section_44_modified.npy
# Processed and saved IDCT for section_45_modified.npy
# Processed and saved IDCT for section_46_modified.npy
# Processed and saved IDCT for section_47_modified.npy
# Processed and saved IDCT for section_48_modified.npy
# Processed and saved IDCT for section_49_modified.npy
# Processed and saved IDCT for section_50_modified.npy
# Processed and saved IDCT for section_51_modified.npy
# Processed and saved IDCT for section_52_modified.npy
# Processed and saved IDCT for section_53_modified.npy
# Processed and saved IDCT for section_54_modified.npy
# Processed and saved IDCT for section_55_modified.npy
# Processed and saved IDCT for section_56_modified.npy
# Processed and saved IDCT for section_57_modified.npy
# Processed and saved IDCT for section_58_modified.npy
# Processed and saved IDCT for section_59_modified.npy
# Processed and saved IDCT for section_60_modified.npy
# Processed and saved IDCT for section_61_modified.npy
# Processed and saved IDCT for section_62_modified.npy
# Processed and saved IDCT for section_63_modified.npy
# Processed and saved IDCT for section_64_modified.npy
# Processed and saved IDCT for section_65_modified.npy
# Processed and saved IDCT for section_66_modified.npy
# Processed and saved IDCT for section_67_modified.npy
# Processed and saved IDCT for section_68_modified.npy
# Processed and saved IDCT for section_69_modified.npy
# Processed and saved IDCT for section_70_modified.npy
# Processed and saved IDCT for section_71_modified.npy
# Processed and saved IDCT for section_72_modified.npy
# Processed and saved IDCT for section_73_modified.npy
# Processed and saved IDCT for section_74_modified.npy
# Processed and saved IDCT for section_75_modified.npy
# Processed and saved IDCT for section_76_modified.npy
# Processed and saved IDCT for section_77_modified.npy
# Processed and saved IDCT for section_78_modified.npy
# Processed and saved IDCT for section_79_modified.npy
# Processed and saved IDCT for section_80_modified.npy
# Processed and saved IDCT for section_81_modified.npy
# Processed and saved IDCT for section_82_modified.npy
# Processed and saved IDCT for section_83_modified.npy
# Processed and saved IDCT for section_84_modified.npy
# Processed and saved IDCT for section_85_modified.npy
# Processed and saved IDCT for section_86_modified.npy
# Processed and saved IDCT for section_87_modified.npy
# Processed and saved IDCT for section_88_modified.npy
# Processed and saved IDCT for section_89_modified.npy
# Processed and saved IDCT for section_90_modified.npy
# Processed and saved IDCT for section_91_modified.npy
# Processed and saved IDCT for section_92_modified.npy
# Processed and saved IDCT for section_93_modified.npy
# Processed and saved IDCT for section_94_modified.npy
# Processed and saved IDCT for section_95_modified.npy
# Processed and saved IDCT for section_96_modified.npy
# Processed and saved IDCT for section_97_modified.npy
# Processed and saved IDCT for section_98_modified.npy
# Processed and saved IDCT for section_99_modified.npy
# Processed and saved IDCT for section_100_modified.npy
# Processed and saved IDCT for section_101_modified.npy
# Processed and saved IDCT for section_102_modified.npy
# Processed and saved IDCT for section_103_modified.npy
# Processed and saved IDCT for section_104_modified.npy
# Processed and saved IDCT for section_105_modified.npy
# Processed and saved IDCT for section_106_modified.npy
# Processed and saved IDCT for section_107_modified.npy
# Processed and saved IDCT for section_108_modified.npy
# Processed and saved IDCT for section_109_modified.npy
# Processed and saved IDCT for section_110_modified.npy
# Processed and saved IDCT for section_111_modified.npy
# Processed and saved IDCT for section_112_modified.npy
# Processed and saved IDCT for section_113_modified.npy
# Processed and saved IDCT for section_114_modified.npy
# Processed and saved IDCT for section_115_modified.npy
# Processed and saved IDCT for section_116_modified.npy
# Processed and saved IDCT for section_117_modified.npy
# Processed and saved IDCT for section_118_modified.npy
# Processed and saved IDCT for section_119_modified.npy
# Processed and saved IDCT for section_120_modified.npy
# Processed and saved IDCT for section_121_modified.npy
# Processed and saved IDCT for section_122_modified.npy
# Processed and saved IDCT for section_123_modified.npy
# Processed and saved IDCT for section_124_modified.npy
# Processed and saved IDCT for section_125_modified.npy
# Processed and saved IDCT for section_126_modified.npy
# Processed and saved IDCT for section_127_modified.npy
# Processed and saved IDCT for section_128_modified.npy
# Processed and saved IDCT for section_129_modified.npy
# Processed and saved IDCT for section_130_modified.npy
# Processed and saved IDCT for section_131_modified.npy
# Processed and saved IDCT for section_132_modified.npy
# Processed and saved IDCT for section_133_modified.npy
# Processed and saved IDCT for section_134_modified.npy
# Processed and saved IDCT for section_135_modified.npy
# Processed and saved IDCT for section_136_modified.npy
# Processed and saved IDCT for section_137_modified.npy
# Processed and saved IDCT for section_138_modified.npy
# Processed and saved IDCT for section_139_modified.npy
# Processed and saved IDCT for section_140_modified.npy
# Processed and saved IDCT for section_141_modified.npy
# Processed and saved IDCT for section_142_modified.npy
# Processed and saved IDCT for section_143_modified.npy
# Processed and saved IDCT for section_144_modified.npy
# Processed and saved IDCT for section_145_modified.npy
# Processed and saved IDCT for section_146_modified.npy
# Processed and saved IDCT for section_147_modified.npy
# Processed and saved IDCT for section_148_modified.npy
# Processed and saved IDCT for section_149_modified.npy
# Processed and saved IDCT for section_150_modified.npy
# Processed and saved IDCT for section_151_modified.npy
# Processed and saved IDCT for section_152_modified.npy
# Processed and saved IDCT for section_153_modified.npy
# Processed and saved IDCT for section_154_modified.npy
# Processed and saved IDCT for section_155_modified.npy
# Processed and saved IDCT for section_156_modified.npy
# Processed and saved IDCT for section_157_modified.npy
# Processed and saved IDCT for section_158_modified.npy
# Processed and saved IDCT for section_159_modified.npy
# Processed and saved IDCT for section_160_modified.npy
# Processed and saved IDCT for section_161_modified.npy
# Processed and saved IDCT for section_162_modified.npy
# Processed and saved IDCT for section_163_modified.npy
# Processed and saved IDCT for section_164_modified.npy
# Processed and saved IDCT for section_165_modified.npy
# Processed and saved IDCT for section_166_modified.npy
# Processed and saved IDCT for section_167_modified.npy
# Processed and saved IDCT for section_168_modified.npy
# Processed and saved IDCT for section_169_modified.npy
# Processed and saved IDCT for section_170_modified.npy
# Processed and saved IDCT for section_171_modified.npy
# Processed and saved IDCT for section_172_modified.npy
# Processed and saved IDCT for section_173_modified.npy
# Processed and saved IDCT for section_174_modified.npy
# Processed and saved IDCT for section_175_modified.npy
# Processed and saved IDCT for section_176_modified.npy
# Processed and saved IDCT for section_177_modified.npy
# Processed and saved IDCT for section_178_modified.npy
# Processed and saved IDCT for section_179_modified.npy
# Processed and saved IDCT for section_180_modified.npy
# Processed and saved IDCT for section_181_modified.npy
# Processed and saved IDCT for section_182_modified.npy
# Processed and saved IDCT for section_183_modified.npy
# Processed and saved IDCT for section_184_modified.npy
# Processed and saved IDCT for section_185_modified.npy
# Processed and saved IDCT for section_186_modified.npy
# Processed and saved IDCT for section_187_modified.npy
# Processed and saved IDCT for section_188_modified.npy
# Processed and saved IDCT for section_189_modified.npy
# Processed and saved IDCT for section_190_modified.npy
# Processed and saved IDCT for section_191_modified.npy
# Processed and saved IDCT for section_192_modified.npy
# Processed and saved IDCT for section_193_modified.npy
# Processed and saved IDCT for section_194_modified.npy
# Processed and saved IDCT for section_195_modified.npy
# Processed and saved IDCT for section_196_modified.npy
# Processed and saved IDCT for section_197_modified.npy
# Processed and saved IDCT for section_198_modified.npy
# Processed and saved IDCT for section_199_modified.npy
# Processed and saved IDCT for section_200_modified.npy
# Processed and saved IDCT for section_201_modified.npy
# Processed and saved IDCT for section_202_modified.npy
# Processed and saved IDCT for section_203_modified.npy
# Processed and saved IDCT for section_204_modified.npy
# Processed and saved IDCT for section_205_modified.npy
# Processed and saved IDCT for section_206_modified.npy
# Processed and saved IDCT for section_207_modified.npy
# Processed and saved IDCT for section_208_modified.npy
# Processed and saved IDCT for section_209_modified.npy
# Processed and saved IDCT for section_210_modified.npy
# Processed and saved IDCT for section_211_modified.npy
# Processed and saved IDCT for section_212_modified.npy
# Processed and saved IDCT for section_213_modified.npy
# Processed and saved IDCT for section_214_modified.npy
# Processed and saved IDCT for section_215_modified.npy
# Processed and saved IDCT for section_216_modified.npy
# Processed and saved IDCT for section_217_modified.npy
# Processed and saved IDCT for section_218_modified.npy
# Processed and saved IDCT for section_219_modified.npy
# Processed and saved IDCT for section_220_modified.npy
# Processed and saved IDCT for section_221_modified.npy
# Processed and saved IDCT for section_222_modified.npy
# Processed and saved IDCT for section_223_modified.npy
# Processed and saved IDCT for section_224_modified.npy
# Processed and saved IDCT for section_225_modified.npy
# Processed and saved IDCT for section_226_modified.npy
# Processed and saved IDCT for section_227_modified.npy
# Processed and saved IDCT for section_228_modified.npy
# Processed and saved IDCT for section_229_modified.npy
# Processed and saved IDCT for section_230_modified.npy
# Processed and saved IDCT for section_231_modified.npy
# Processed and saved IDCT for section_232_modified.npy
# Processed and saved IDCT for section_233_modified.npy
# Processed and saved IDCT for section_234_modified.npy
# Processed and saved IDCT for section_235_modified.npy
# Processed and saved IDCT for section_236_modified.npy
# Processed and saved IDCT for section_237_modified.npy
# Processed and saved IDCT for section_238_modified.npy
# Processed and saved IDCT for section_239_modified.npy
# Processed and saved IDCT for section_240_modified.npy
# Processed and saved IDCT for section_241_modified.npy
# Processed and saved IDCT for section_242_modified.npy
# Processed and saved IDCT for section_243_modified.npy
# Processed and saved IDCT for section_244_modified.npy
# Processed and saved IDCT for section_245_modified.npy
# Processed and saved IDCT for section_246_modified.npy
# Processed and saved IDCT for section_247_modified.npy
# Processed and saved IDCT for section_248_modified.npy
# Processed and saved IDCT for section_249_modified.npy
# Processed and saved IDCT for section_250_modified.npy
# Processed and saved IDCT for section_251_modified.npy
# Processed and saved IDCT for section_252_modified.npy
# Processed and saved IDCT for section_253_modified.npy
# Processed and saved IDCT for section_254_modified.npy
# Processed and saved IDCT for section_255_modified.npy
# Processed and saved IDCT for section_256_modified.npy
# Processed and saved IDCT for section_257_modified.npy
# Processed and saved IDCT for section_258_modified.npy
# Processed and saved IDCT for section_259_modified.npy
# Processed and saved IDCT for section_260_modified.npy
# Processed and saved IDCT for section_261_modified.npy
# Processed and saved IDCT for section_262_modified.npy
# Processed and saved IDCT for section_263_modified.npy
# Processed and saved IDCT for section_264_modified.npy
# Processed and saved IDCT for section_265_modified.npy
# Processed and saved IDCT for section_266_modified.npy
# Processed and saved IDCT for section_267_modified.npy
# Processed and saved IDCT for section_268_modified.npy
# Processed and saved IDCT for section_269_modified.npy
# Processed and saved IDCT for section_270_modified.npy
# Processed and saved IDCT for section_271_modified.npy
# Processed and saved IDCT for section_272_modified.npy
# Processed and saved IDCT for section_273_modified.npy
# Processed and saved IDCT for section_274_modified.npy
# Processed and saved IDCT for section_275_modified.npy
# Processed and saved IDCT for section_276_modified.npy
# Processed and saved IDCT for section_277_modified.npy
# Processed and saved IDCT for section_278_modified.npy
# Processed and saved IDCT for section_279_modified.npy
# Processed and saved IDCT for section_280_modified.npy
# Processed and saved IDCT for section_281_modified.npy
# Processed and saved IDCT for section_282_modified.npy
# Processed and saved IDCT for section_283_modified.npy
# Processed and saved IDCT for section_284_modified.npy
# Processed and saved IDCT for section_285_modified.npy
# Processed and saved IDCT for section_286_modified.npy
# Processed and saved IDCT for section_287_modified.npy
# Processed and saved IDCT for section_288_modified.npy
# Processed and saved IDCT for section_289_modified.npy
# Processed and saved IDCT for section_290_modified.npy
# Processed and saved IDCT for section_291_modified.npy
# Processed and saved IDCT for section_292_modified.npy
# Processed and saved IDCT for section_293_modified.npy
# Processed and saved IDCT for section_294_modified.npy
# Processed and saved IDCT for section_295_modified.npy
# Processed and saved IDCT for section_296_modified.npy
# Processed and saved IDCT for section_297_modified.npy
# Processed and saved IDCT for section_298_modified.npy
# Processed and saved IDCT for section_299_modified.npy
# Processed and saved IDCT for section_300_modified.npy
# Processed and saved IDCT for section_301_modified.npy
# Processed and saved IDCT for section_302_modified.npy
# Processed and saved IDCT for section_303_modified.npy
# Processed and saved IDCT for section_304_modified.npy
# Processed and saved IDCT for section_305_modified.npy
# Processed and saved IDCT for section_306_modified.npy
# Processed and saved IDCT for section_307_modified.npy
# Processed and saved IDCT for section_308_modified.npy
# Processed and saved IDCT for section_309_modified.npy
# Processed and saved IDCT for section_310_modified.npy
# Processed and saved IDCT for section_311_modified.npy
# Processed and saved IDCT for section_312_modified.npy
# Processed and saved IDCT for section_313_modified.npy
# Processed and saved IDCT for section_314_modified.npy
# Processed and saved IDCT for section_315_modified.npy
# Processed and saved IDCT for section_316_modified.npy
# Processed and saved IDCT for section_317_modified.npy
# Processed and saved IDCT for section_318_modified.npy
# Processed and saved IDCT for section_319_modified.npy
# Processed and saved IDCT for section_320_modified.npy
# Processed and saved IDCT for section_321_modified.npy
# Processed and saved IDCT for section_322_modified.npy
# Processed and saved IDCT for section_323_modified.npy
# Processed and saved IDCT for section_324_modified.npy
# Processed and saved IDCT for section_325_modified.npy
# Processed and saved IDCT for section_326_modified.npy
# Processed and saved IDCT for section_327_modified.npy
# Processed and saved IDCT for section_328_modified.npy
# Processed and saved IDCT for section_329_modified.npy
# Processed and saved IDCT for section_330_modified.npy
# Processed and saved IDCT for section_331_modified.npy
# Processed and saved IDCT for section_332_modified.npy
# Processed and saved IDCT for section_333_modified.npy
# Processed and saved IDCT for section_334_modified.npy
# Processed and saved IDCT for section_335_modified.npy
# Processed and saved IDCT for section_336_modified.npy
# Processed and saved IDCT for section_337_modified.npy
# Processed and saved IDCT for section_338_modified.npy
# Processed and saved IDCT for section_339_modified.npy
# Processed and saved IDCT for section_340_modified.npy
# Processed and saved IDCT for section_341_modified.npy
# Processed and saved IDCT for section_342_modified.npy
# Processed and saved IDCT for section_343_modified.npy
# Processed and saved IDCT for section_344_modified.npy
# Processed and saved IDCT for section_345_modified.npy
# Processed and saved IDCT for section_346_modified.npy
# Processed and saved IDCT for section_347_modified.npy
# Processed and saved IDCT for section_348_modified.npy
# Processed and saved IDCT for section_349_modified.npy
# Processed and saved IDCT for section_350_modified.npy
# Processed and saved IDCT for section_351_modified.npy
# Processed and saved IDCT for section_352_modified.npy
# Processed and saved IDCT for section_353_modified.npy
# Processed and saved IDCT for section_354_modified.npy
# Processed and saved IDCT for section_355_modified.npy
# Processed and saved IDCT for section_356_modified.npy
# Processed and saved IDCT for section_357_modified.npy
# Processed and saved IDCT for section_358_modified.npy
# Processed and saved IDCT for section_359_modified.npy
# Processed and saved IDCT for section_360_modified.npy
# Processed and saved IDCT for section_361_modified.npy
# Processed and saved IDCT for section_362_modified.npy
# Processed and saved IDCT for section_363_modified.npy
# Processed and saved IDCT for section_364_modified.npy
# Processed and saved IDCT for section_365_modified.npy
# Processed and saved IDCT for section_366_modified.npy
# Processed and saved IDCT for section_367_modified.npy
# Processed and saved IDCT for section_368_modified.npy
# Processed and saved IDCT for section_369_modified.npy
# Processed and saved IDCT for section_370_modified.npy
# Processed and saved IDCT for section_371_modified.npy
# Processed and saved IDCT for section_372_modified.npy
# Processed and saved IDCT for section_373_modified.npy
# Processed and saved IDCT for section_374_modified.npy
# Processed and saved IDCT for section_375_modified.npy
# Processed and saved IDCT for section_376_modified.npy
# Processed and saved IDCT for section_377_modified.npy
# Processed and saved IDCT for section_378_modified.npy
# Processed and saved IDCT for section_379_modified.npy
# Processed and saved IDCT for section_380_modified.npy
# Processed and saved IDCT for section_381_modified.npy
# Processed and saved IDCT for section_382_modified.npy
# Processed and saved IDCT for section_383_modified.npy
# Processed and saved IDCT for section_384_modified.npy
# Processed and saved IDCT for section_385_modified.npy
# Processed and saved IDCT for section_386_modified.npy
# Processed and saved IDCT for section_387_modified.npy
# Processed and saved IDCT for section_388_modified.npy
# Processed and saved IDCT for section_389_modified.npy
# Processed and saved IDCT for section_390_modified.npy
# Processed and saved IDCT for section_391_modified.npy
# Processed and saved IDCT for section_392_modified.npy
# Processed and saved IDCT for section_393_modified.npy
# Processed and saved IDCT for section_394_modified.npy
# Processed and saved IDCT for section_395_modified.npy
# Processed and saved IDCT for section_396_modified.npy
# Processed and saved IDCT for section_397_modified.npy
# Processed and saved IDCT for section_398_modified.npy
# Processed and saved IDCT for section_399_modified.npy
# Processed and saved IDCT for section_400_modified.npy
# Processed and saved IDCT for section_401_modified.npy
# Processed and saved IDCT for section_402_modified.npy
# Processed and saved IDCT for section_403_modified.npy
# Processed and saved IDCT for section_404_modified.npy
# Processed and saved IDCT for section_405_modified.npy
# Processed and saved IDCT for section_406_modified.npy
# Processed and saved IDCT for section_407_modified.npy
# Processed and saved IDCT for section_408_modified.npy
# Processed and saved IDCT for section_409_modified.npy
# Processed and saved IDCT for section_410_modified.npy
# Processed and saved IDCT for section_411_modified.npy
# Processed and saved IDCT for section_412_modified.npy
# Processed and saved IDCT for section_413_modified.npy
# Processed and saved IDCT for section_414_modified.npy
# Processed and saved IDCT for section_415_modified.npy
# Processed and saved IDCT for section_416_modified.npy
# Processed and saved IDCT for section_417_modified.npy
# Processed and saved IDCT for section_418_modified.npy
# Processed and saved IDCT for section_419_modified.npy
# Processed and saved IDCT for section_420_modified.npy
# Processed and saved IDCT for section_421_modified.npy
# Processed and saved IDCT for section_422_modified.npy
# Processed and saved IDCT for section_423_modified.npy
# Processed and saved IDCT for section_424_modified.npy
# Processed and saved IDCT for section_425_modified.npy
# Processed and saved IDCT for section_426_modified.npy
# Processed and saved IDCT for section_427_modified.npy
# Processed and saved IDCT for section_428_modified.npy
# Processed and saved IDCT for section_429_modified.npy
# Processed and saved IDCT for section_430_modified.npy
# Processed and saved IDCT for section_431_modified.npy
# Processed and saved IDCT for section_432_modified.npy
# Processed and saved IDCT for section_433_modified.npy
# Processed and saved IDCT for section_434_modified.npy
# Processed and saved IDCT for section_435_modified.npy
# Processed and saved IDCT for section_436_modified.npy
# Processed and saved IDCT for section_437_modified.npy
# Processed and saved IDCT for section_438_modified.npy
# Processed and saved IDCT for section_439_modified.npy
# Processed and saved IDCT for section_440_modified.npy
# Processed and saved IDCT for section_441_modified.npy
# Processed and saved IDCT for section_442_modified.npy
# Processed and saved IDCT for section_443_modified.npy
# Processed and saved IDCT for section_444_modified.npy
# Processed and saved IDCT for section_445_modified.npy
# Processed and saved IDCT for section_446_modified.npy
# Processed and saved IDCT for section_447_modified.npy
# Processed and saved IDCT for section_448_modified.npy
# Processed and saved IDCT for section_449_modified.npy
# Processed and saved IDCT for section_450_modified.npy
# Processed and saved IDCT for section_451_modified.npy
# Processed and saved IDCT for section_452_modified.npy
# Processed and saved IDCT for section_453_modified.npy
# Processed and saved IDCT for section_454_modified.npy
# Processed and saved IDCT for section_455_modified.npy
# Processed and saved IDCT for section_456_modified.npy
# Processed and saved IDCT for section_457_modified.npy
# Processed and saved IDCT for section_458_modified.npy
# Processed and saved IDCT for section_459_modified.npy
# Processed and saved IDCT for section_460_modified.npy
# Processed and saved IDCT for section_461_modified.npy
# Processed and saved IDCT for section_462_modified.npy
# Processed and saved IDCT for section_463_modified.npy
# Processed and saved IDCT for section_464_modified.npy
# Processed and saved IDCT for section_465_modified.npy
# Processed and saved IDCT for section_466_modified.npy
# Processed and saved IDCT for section_467_modified.npy
# Processed and saved IDCT for section_468_modified.npy
# Processed and saved IDCT for section_469_modified.npy
# Processed and saved IDCT for section_470_modified.npy
# Processed and saved IDCT for section_471_modified.npy
# Processed and saved IDCT for section_472_modified.npy
# Processed and saved IDCT for section_473_modified.npy
# Processed and saved IDCT for section_474_modified.npy
# Processed and saved IDCT for section_475_modified.npy
# Processed and saved IDCT for section_476_modified.npy
# Processed and saved IDCT for section_477_modified.npy
# Processed and saved IDCT for section_478_modified.npy
# Processed and saved IDCT for section_479_modified.npy
# Processed and saved IDCT for section_480_modified.npy
# Processed and saved IDCT for section_481_modified.npy
# Processed and saved IDCT for section_482_modified.npy
# Processed and saved IDCT for section_483_modified.npy
# Processed and saved IDCT for section_484_modified.npy
# Processed and saved IDCT for section_485_modified.npy
# Processed and saved IDCT for section_486_modified.npy
# Processed and saved IDCT for section_487_modified.npy
# Processed and saved IDCT for section_488_modified.npy
# Processed and saved IDCT for section_489_modified.npy
# Processed and saved IDCT for section_490_modified.npy
# Processed and saved IDCT for section_491_modified.npy
# Processed and saved IDCT for section_492_modified.npy
# Processed and saved IDCT for section_493_modified.npy
# Processed and saved IDCT for section_494_modified.npy
# Processed and saved IDCT for section_495_modified.npy
# Processed and saved IDCT for section_496_modified.npy
# Processed and saved IDCT for section_497_modified.npy
# Processed and saved IDCT for section_498_modified.npy
# Processed and saved IDCT for section_499_modified.npy
# Processed and saved IDCT for section_500_modified.npy
# Processed and saved IDCT for section_501_modified.npy
# Processed and saved IDCT for section_502_modified.npy
# Processed and saved IDCT for section_503_modified.npy
# Processed and saved IDCT for section_504_modified.npy
# Processed and saved IDCT for section_505_modified.npy
# Processed and saved IDCT for section_506_modified.npy
# Processed and saved IDCT for section_507_modified.npy
# Processed and saved IDCT for section_508_modified.npy
# Processed and saved IDCT for section_509_modified.npy
# Processed and saved IDCT for section_510_modified.npy
# Processed and saved IDCT for section_511_modified.npy
# Processed and saved IDCT for section_512_modified.npy
# Processed and saved IDCT for section_513_modified.npy
# Processed and saved IDCT for section_514_modified.npy
# Processed and saved IDCT for section_515_modified.npy
# Processed and saved IDCT for section_516_modified.npy
# Processed and saved IDCT for section_517_modified.npy
# Processed and saved IDCT for section_518_modified.npy
# Processed and saved IDCT for section_519_modified.npy
# Processed and saved IDCT for section_520_modified.npy
# Processed and saved IDCT for section_521_modified.npy
# Processed and saved IDCT for section_522_modified.npy
# Processed and saved IDCT for section_523_modified.npy
# Processed and saved IDCT for section_524_modified.npy
# Processed and saved IDCT for section_525_modified.npy
# Processed and saved IDCT for section_526_modified.npy
# Processed and saved IDCT for section_527_modified.npy
# Processed and saved IDCT for section_528_modified.npy
# Processed and saved IDCT for section_529_modified.npy
# Processed and saved IDCT for section_530_modified.npy
# Processed and saved IDCT for section_531_modified.npy
# Processed and saved IDCT for section_532_modified.npy
# Processed and saved IDCT for section_533_modified.npy
# Processed and saved IDCT for section_534_modified.npy
# Processed and saved IDCT for section_535_modified.npy
# Processed and saved IDCT for section_536_modified.npy
# Processed and saved IDCT for section_537_modified.npy
# Processed and saved IDCT for section_538_modified.npy
# Processed and saved IDCT for section_539_modified.npy
# Processed and saved IDCT for section_540_modified.npy
# Processed and saved IDCT for section_541_modified.npy
# Processed and saved IDCT for section_542_modified.npy
# Processed and saved IDCT for section_543_modified.npy
# Processed and saved IDCT for section_544_modified.npy
# Processed and saved IDCT for section_545_modified.npy
# Processed and saved IDCT for section_546_modified.npy
# Processed and saved IDCT for section_547_modified.npy
# Processed and saved IDCT for section_548_modified.npy
# Processed and saved IDCT for section_549_modified.npy
# Processed and saved IDCT for section_550_modified.npy
# Processed and saved IDCT for section_551_modified.npy
# Processed and saved IDCT for section_552_modified.npy
# Processed and saved IDCT for section_553_modified.npy
# Processed and saved IDCT for section_554_modified.npy
# Processed and saved IDCT for section_555_modified.npy
# Processed and saved IDCT for section_556_modified.npy
# Processed and saved IDCT for section_557_modified.npy
# Processed and saved IDCT for section_558_modified.npy
# Processed and saved IDCT for section_559_modified.npy
# Processed and saved IDCT for section_560_modified.npy
# Processed and saved IDCT for section_561_modified.npy
# Processed and saved IDCT for section_562_modified.npy
# Processed and saved IDCT for section_563_modified.npy
# Processed and saved IDCT for section_564_modified.npy
# Processed and saved IDCT for section_565_modified.npy
# Processed and saved IDCT for section_566_modified.npy
# Processed and saved IDCT for section_567_modified.npy
# Processed and saved IDCT for section_568_modified.npy
# Processed and saved IDCT for section_569_modified.npy
# Processed and saved IDCT for section_570_modified.npy
# Processed and saved IDCT for section_571_modified.npy
# Processed and saved IDCT for section_572_modified.npy
# Processed and saved IDCT for section_573_modified.npy
# Processed and saved IDCT for section_574_modified.npy
# Processed and saved IDCT for section_575_modified.npy
# Processed and saved IDCT for section_576_modified.npy
# Processed and saved IDCT for section_577_modified.npy
# Processed and saved IDCT for section_578_modified.npy
# Processed and saved IDCT for section_579_modified.npy
# Processed and saved IDCT for section_580_modified.npy
# Processed and saved IDCT for section_581_modified.npy
# Processed and saved IDCT for section_582_modified.npy
# Processed and saved IDCT for section_583_modified.npy
# Processed and saved IDCT for section_584_modified.npy
# Processed and saved IDCT for section_585_modified.npy
# Processed and saved IDCT for section_586_modified.npy
# Processed and saved IDCT for section_587_modified.npy
# Processed and saved IDCT for section_588_modified.npy
# Processed and saved IDCT for section_589_modified.npy
# Processed and saved IDCT for section_590_modified.npy
# Processed and saved IDCT for section_591_modified.npy
# Processed and saved IDCT for section_592_modified.npy
# Processed and saved IDCT for section_593_modified.npy
# Processed and saved IDCT for section_594_modified.npy
# Processed and saved IDCT for section_595_modified.npy
# Processed and saved IDCT for section_596_modified.npy
# Processed and saved IDCT for section_597_modified.npy
# Processed and saved IDCT for section_598_modified.npy
# Processed and saved IDCT for section_599_modified.npy
# Processed and saved IDCT for section_600_modified.npy
# Processed and saved IDCT for section_601_modified.npy
# Processed and saved IDCT for section_602_modified.npy
# Processed and saved IDCT for section_603_modified.npy
# Processed and saved IDCT for section_604_modified.npy
# Processed and saved IDCT for section_605_modified.npy
# Processed and saved IDCT for section_606_modified.npy
# Processed and saved IDCT for section_607_modified.npy
# Processed and saved IDCT for section_608_modified.npy
# Processed and saved IDCT for section_609_modified.npy
# Processed and saved IDCT for section_610_modified.npy
# Processed and saved IDCT for section_611_modified.npy
# Processed and saved IDCT for section_612_modified.npy
# Processed and saved IDCT for section_613_modified.npy
# Processed and saved IDCT for section_614_modified.npy
# Processed and saved IDCT for section_615_modified.npy
# Processed and saved IDCT for section_616_modified.npy
# Processed and saved IDCT for section_617_modified.npy
# Processed and saved IDCT for section_618_modified.npy
# Processed and saved IDCT for section_619_modified.npy
# Processed and saved IDCT for section_620_modified.npy
# Processed and saved IDCT for section_621_modified.npy
# Processed and saved IDCT for section_622_modified.npy
# Processed and saved IDCT for section_623_modified.npy
# Processed and saved IDCT for section_624_modified.npy
# Processed and saved IDCT for section_625_modified.npy
# Processed and saved IDCT for section_626_modified.npy
# Processed and saved IDCT for section_627_modified.npy
# Processed and saved IDCT for section_628_modified.npy
# Processed and saved IDCT for section_629_modified.npy
# Processed and saved IDCT for section_630_modified.npy
# Processed and saved IDCT for section_631_modified.npy
# Processed and saved IDCT for section_632_modified.npy
# Processed and saved IDCT for section_633_modified.npy
# Processed and saved IDCT for section_634_modified.npy
# Processed and saved IDCT for section_635_modified.npy
# Processed and saved IDCT for section_636_modified.npy
# Processed and saved IDCT for section_637_modified.npy
# Processed and saved IDCT for section_638_modified.npy
# Processed and saved IDCT for section_639_modified.npy
# Processed and saved IDCT for section_640_modified.npy
# Processed and saved IDCT for section_641_modified.npy
# Processed and saved IDCT for section_642_modified.npy
# Processed and saved IDCT for section_643_modified.npy
# Processed and saved IDCT for section_644_modified.npy
# Processed and saved IDCT for section_645_modified.npy
# Processed and saved IDCT for section_646_modified.npy
# Processed and saved IDCT for section_647_modified.npy
# Processed and saved IDCT for section_648_modified.npy
# Processed and saved IDCT for section_649_modified.npy
# Processed and saved IDCT for section_650_modified.npy
# Processed and saved IDCT for section_651_modified.npy
# Processed and saved IDCT for section_652_modified.npy
# Processed and saved IDCT for section_653_modified.npy
# Processed and saved IDCT for section_654_modified.npy
# Processed and saved IDCT for section_655_modified.npy
# Processed and saved IDCT for section_656_modified.npy
# Processed and saved IDCT for section_657_modified.npy
# Processed and saved IDCT for section_658_modified.npy
# Processed and saved IDCT for section_659_modified.npy
# Processed and saved IDCT for section_660_modified.npy
# Processed and saved IDCT for section_661_modified.npy
# Processed and saved IDCT for section_662_modified.npy
# Processed and saved IDCT for section_663_modified.npy
# Processed and saved IDCT for section_664_modified.npy
# Processed and saved IDCT for section_665_modified.npy
# Processed and saved IDCT for section_666_modified.npy
# Processed and saved IDCT for section_667_modified.npy
# Processed and saved IDCT for section_668_modified.npy
# Processed and saved IDCT for section_669_modified.npy
# Processed and saved IDCT for section_670_modified.npy
# Processed and saved IDCT for section_671_modified.npy
# Processed and saved IDCT for section_672_modified.npy
# Processed and saved IDCT for section_673_modified.npy
# Processed and saved IDCT for section_674_modified.npy
# Processed and saved IDCT for section_675_modified.npy
# Processed and saved IDCT for section_676_modified.npy
# Processed and saved IDCT for section_677_modified.npy
# Processed and saved IDCT for section_678_modified.npy
# Processed and saved IDCT for section_679_modified.npy
# Processed and saved IDCT for section_680_modified.npy
# Processed and saved IDCT for section_681_modified.npy
# Processed and saved IDCT for section_682_modified.npy
# Processed and saved IDCT for section_683_modified.npy
# Processed and saved IDCT for section_684_modified.npy
# Processed and saved IDCT for section_685_modified.npy
# Processed and saved IDCT for section_686_modified.npy
# Processed and saved IDCT for section_687_modified.npy
# Processed and saved IDCT for section_688_modified.npy
# Processed and saved IDCT for section_689_modified.npy
# Processed and saved IDCT for section_690_modified.npy
# Processed and saved IDCT for section_691_modified.npy
# Processed and saved IDCT for section_692_modified.npy
# Processed and saved IDCT for section_693_modified.npy
# Processed and saved IDCT for section_694_modified.npy
# Processed and saved IDCT for section_695_modified.npy
# Processed and saved IDCT for section_696_modified.npy
# Processed and saved IDCT for section_697_modified.npy
# Processed and saved IDCT for section_698_modified.npy
# Processed and saved IDCT for section_699_modified.npy
# Processed and saved IDCT for section_700_modified.npy
# Processed and saved IDCT for section_701_modified.npy
# Processed and saved IDCT for section_702_modified.npy
# Processed and saved IDCT for section_703_modified.npy
# Processed and saved IDCT for section_704_modified.npy
# Processed and saved IDCT for section_705_modified.npy
# Processed and saved IDCT for section_706_modified.npy
# Processed and saved IDCT for section_707_modified.npy
# Processed and saved IDCT for section_708_modified.npy
# Processed and saved IDCT for section_709_modified.npy
# Processed and saved IDCT for section_710_modified.npy
# Processed and saved IDCT for section_711_modified.npy
# Processed and saved IDCT for section_712_modified.npy
# Processed and saved IDCT for section_713_modified.npy
# Processed and saved IDCT for section_714_modified.npy
# Processed and saved IDCT for section_715_modified.npy
# Processed and saved IDCT for section_716_modified.npy
# Processed and saved IDCT for section_717_modified.npy
# Processed and saved IDCT for section_718_modified.npy
# Processed and saved IDCT for section_719_modified.npy
# Processed and saved IDCT for section_720_modified.npy
# Processed and saved IDCT for section_721_modified.npy
# Processed and saved IDCT for section_722_modified.npy
# Processed and saved IDCT for section_723_modified.npy
# Processed and saved IDCT for section_724_modified.npy
# Processed and saved IDCT for section_725_modified.npy
# Processed and saved IDCT for section_726_modified.npy
# Processed and saved IDCT for section_727_modified.npy
# Processed and saved IDCT for section_728_modified.npy
# Processed and saved IDCT for section_729_modified.npy
# Processed and saved IDCT for section_730_modified.npy
# Processed and saved IDCT for section_731_modified.npy
# Processed and saved IDCT for section_732_modified.npy
# Processed and saved IDCT for section_733_modified.npy
# Processed and saved IDCT for section_734_modified.npy
# Processed and saved IDCT for section_735_modified.npy
# Processed and saved IDCT for section_736_modified.npy
# Processed and saved IDCT for section_737_modified.npy
# Processed and saved IDCT for section_738_modified.npy
# Processed and saved IDCT for section_739_modified.npy
# Processed and saved IDCT for section_740_modified.npy
# Processed and saved IDCT for section_741_modified.npy
# Processed and saved IDCT for section_742_modified.npy
# Processed and saved IDCT for section_743_modified.npy
# Processed and saved IDCT for section_744_modified.npy
# Processed and saved IDCT for section_745_modified.npy
# Processed and saved IDCT for section_746_modified.npy
# Processed and saved IDCT for section_747_modified.npy
# Processed and saved IDCT for section_748_modified.npy
# Processed and saved IDCT for section_749_modified.npy
# Processed and saved IDCT for section_750_modified.npy
# Processed and saved IDCT for section_751_modified.npy
# Processed and saved IDCT for section_752_modified.npy
# Processed and saved IDCT for section_753_modified.npy
# Processed and saved IDCT for section_754_modified.npy
# Processed and saved IDCT for section_755_modified.npy
# Processed and saved IDCT for section_756_modified.npy
# Processed and saved IDCT for section_757_modified.npy
# Processed and saved IDCT for section_758_modified.npy
# Processed and saved IDCT for section_759_modified.npy
# Processed and saved IDCT for section_760_modified.npy
# Processed and saved IDCT for section_761_modified.npy
# Processed and saved IDCT for section_762_modified.npy
# Processed and saved IDCT for section_763_modified.npy
# Processed and saved IDCT for section_764_modified.npy
# Processed and saved IDCT for section_765_modified.npy
# Processed and saved IDCT for section_766_modified.npy
# Processed and saved IDCT for section_767_modified.npy
# Processed and saved IDCT for section_768_modified.npy
# Processed and saved IDCT for section_769_modified.npy
# Processed and saved IDCT for section_770_modified.npy
# Processed and saved IDCT for section_771_modified.npy
# Processed and saved IDCT for section_772_modified.npy
# Processed and saved IDCT for section_773_modified.npy
# Processed and saved IDCT for section_774_modified.npy
# Processed and saved IDCT for section_775_modified.npy
# Processed and saved IDCT for section_776_modified.npy
# Processed and saved IDCT for section_777_modified.npy
# Processed and saved IDCT for section_778_modified.npy
# Processed and saved IDCT for section_779_modified.npy
# Processed and saved IDCT for section_780_modified.npy
# Processed and saved IDCT for section_781_modified.npy
# Processed and saved IDCT for section_782_modified.npy
# Processed and saved IDCT for section_783_modified.npy
# Processed and saved IDCT for section_784_modified.npy
# Processed and saved IDCT for section_785_modified.npy
# Processed and saved IDCT for section_786_modified.npy
# Processed and saved IDCT for section_787_modified.npy
# Processed and saved IDCT for section_788_modified.npy
# Processed and saved IDCT for section_789_modified.npy
# Processed and saved IDCT for section_790_modified.npy
# Processed and saved IDCT for section_791_modified.npy
# Processed and saved IDCT for section_792_modified.npy
# Processed and saved IDCT for section_793_modified.npy
# Processed and saved IDCT for section_794_modified.npy
# Processed and saved IDCT for section_795_modified.npy
# Processed and saved IDCT for section_796_modified.npy
# Processed and saved IDCT for section_797_modified.npy
# Processed and saved IDCT for section_798_modified.npy
# Processed and saved IDCT for section_799_modified.npy
# Processed and saved IDCT for section_800_modified.npy
# Processed and saved IDCT for section_801_modified.npy
# Processed and saved IDCT for section_802_modified.npy
# Processed and saved IDCT for section_803_modified.npy
# Processed and saved IDCT for section_804_modified.npy
# Processed and saved IDCT for section_805_modified.npy
# Processed and saved IDCT for section_806_modified.npy
# Processed and saved IDCT for section_807_modified.npy
# Processed and saved IDCT for section_808_modified.npy
# Processed and saved IDCT for section_809_modified.npy
# Processed and saved IDCT for section_810_modified.npy
# Processed and saved IDCT for section_811_modified.npy
# Processed and saved IDCT for section_812_modified.npy
# Processed and saved IDCT for section_813_modified.npy
# Processed and saved IDCT for section_814_modified.npy
# Processed and saved IDCT for section_815_modified.npy
# Processed and saved IDCT for section_816_modified.npy
# Processed and saved IDCT for section_817_modified.npy
# Processed and saved IDCT for section_818_modified.npy
# Processed and saved IDCT for section_819_modified.npy
# Processed and saved IDCT for section_820_modified.npy
# Processed and saved IDCT for section_821_modified.npy
# Processed and saved IDCT for section_822_modified.npy
# Processed and saved IDCT for section_823_modified.npy
# Processed and saved IDCT for section_824_modified.npy
# Processed and saved IDCT for section_825_modified.npy
# Processed and saved IDCT for section_826_modified.npy
# Processed and saved IDCT for section_827_modified.npy
# Processed and saved IDCT for section_828_modified.npy
# Processed and saved IDCT for section_829_modified.npy
# Processed and saved IDCT for section_830_modified.npy
# Processed and saved IDCT for section_831_modified.npy
# Processed and saved IDCT for section_832_modified.npy
# Processed and saved IDCT for section_833_modified.npy
# Processed and saved IDCT for section_834_modified.npy
# Processed and saved IDCT for section_835_modified.npy
# Processed and saved IDCT for section_836_modified.npy
# Processed and saved IDCT for section_837_modified.npy
# Processed and saved IDCT for section_838_modified.npy
# Processed and saved IDCT for section_839_modified.npy
# Processed and saved IDCT for section_840_modified.npy
# Processed and saved IDCT for section_841_modified.npy
# Processed and saved IDCT for section_842_modified.npy
# Processed and saved IDCT for section_843_modified.npy
# Processed and saved IDCT for section_844_modified.npy
# Processed and saved IDCT for section_845_modified.npy
# Processed and saved IDCT for section_846_modified.npy
# Processed and saved IDCT for section_847_modified.npy
# Processed and saved IDCT for section_848_modified.npy
# Processed and saved IDCT for section_849_modified.npy
# Processed and saved IDCT for section_850_modified.npy
# Processed and saved IDCT for section_851_modified.npy
# Processed and saved IDCT for section_852_modified.npy
# Processed and saved IDCT for section_853_modified.npy
# Processed and saved IDCT for section_854_modified.npy
# Processed and saved IDCT for section_855_modified.npy
# Processed and saved IDCT for section_856_modified.npy
# Processed and saved IDCT for section_857_modified.npy
# Processed and saved IDCT for section_858_modified.npy
# Processed and saved IDCT for section_859_modified.npy
# Processed and saved IDCT for section_860_modified.npy
# Processed and saved IDCT for section_861_modified.npy
# Processed and saved IDCT for section_862_modified.npy
# Processed and saved IDCT for section_863_modified.npy
# Processed and saved IDCT for section_864_modified.npy
# Processed and saved IDCT for section_865_modified.npy
# Processed and saved IDCT for section_866_modified.npy
# Processed and saved IDCT for section_867_modified.npy
# Processed and saved IDCT for section_868_modified.npy
# Processed and saved IDCT for section_869_modified.npy
# Processed and saved IDCT for section_870_modified.npy
# Processed and saved IDCT for section_871_modified.npy
# Processed and saved IDCT for section_872_modified.npy
# Processed and saved IDCT for section_873_modified.npy
# Processed and saved IDCT for section_874_modified.npy
# Processed and saved IDCT for section_875_modified.npy
# Processed and saved IDCT for section_876_modified.npy
# Processed and saved IDCT for section_877_modified.npy
# Processed and saved IDCT for section_878_modified.npy
# Processed and saved IDCT for section_879_modified.npy
# Processed and saved IDCT for section_880_modified.npy
# Processed and saved IDCT for section_881_modified.npy
# Processed and saved IDCT for section_882_modified.npy
# Processed and saved IDCT for section_883_modified.npy
# Processed and saved IDCT for section_884_modified.npy
# Processed and saved IDCT for section_885_modified.npy
# Processed and saved IDCT for section_886_modified.npy
# Processed and saved IDCT for section_887_modified.npy
# Processed and saved IDCT for section_888_modified.npy
# Processed and saved IDCT for section_889_modified.npy
# Processed and saved IDCT for section_890_modified.npy
# ...
# Processed and saved IDCT for section_3807_modified.npy
# Processed and saved IDCT for section_3808_modified.npy
# Processed and saved IDCT for section_3809_modified.npy
# Processed and saved IDCT for section_3810_modified.npy
# Processed and saved IDCT for section_3811_modified.npy
# Processed and saved IDCT for section_3812_modified.npy
# Processed and saved IDCT for section_3813_modified.npy
# Processed and saved IDCT for section_3814_modified.npy
# Processed and saved IDCT for section_3815_modified.npy
# Processed and saved IDCT for section_3816_modified.npy
# Processed and saved IDCT for section_3817_modified.npy
# Processed and saved IDCT for section_3818_modified.npy
# Processed and saved IDCT for section_3819_modified.npy
# Processed and saved IDCT for section_3820_modified.npy
# Processed and saved IDCT for section_3821_modified.npy
# Processed and saved IDCT for section_3822_modified.npy
# Processed and saved IDCT for section_3823_modified.npy
# Processed and saved IDCT for section_3824_modified.npy
# Processed and saved IDCT for section_3825_modified.npy
# Processed and saved IDCT for section_3826_modified.npy
# Processed and saved IDCT for section_3827_modified.npy
# Processed and saved IDCT for section_3828_modified.npy
# Processed and saved IDCT for section_3829_modified.npy
# Processed and saved IDCT for section_3830_modified.npy
# Processed and saved IDCT for section_3831_modified.npy
# Processed and saved IDCT for section_3832_modified.npy
# Processed and saved IDCT for section_3833_modified.npy
# Processed and saved IDCT for section_3834_modified.npy
# Processed and saved IDCT for section_3835_modified.npy
# Processed and saved IDCT for section_3836_modified.npy
# Processed and saved IDCT for section_3837_modified.npy
# Processed and saved IDCT for section_3838_modified.npy
# Processed and saved IDCT for section_3839_modified.npy
# Processed and saved IDCT for section_3840_modified.npy
# Processed and saved IDCT for section_3841_modified.npy
# Processed and saved IDCT for section_3842_modified.npy
# Processed and saved IDCT for section_3843_modified.npy
# Processed and saved IDCT for section_3844_modified.npy
# Processed and saved IDCT for section_3845_modified.npy
# Processed and saved IDCT for section_3846_modified.npy
# Processed and saved IDCT for section_3847_modified.npy
# Processed and saved IDCT for section_3848_modified.npy
# Processed and saved IDCT for section_3849_modified.npy
# Processed and saved IDCT for section_3850_modified.npy
# Processed and saved IDCT for section_3851_modified.npy
# Processed and saved IDCT for section_3852_modified.npy
# Processed and saved IDCT for section_3853_modified.npy
# Processed and saved IDCT for section_3854_modified.npy
# Processed and saved IDCT for section_3855_modified.npy
# Processed and saved IDCT for section_3856_modified.npy
# Processed and saved IDCT for section_3857_modified.npy
# Processed and saved IDCT for section_3858_modified.npy
# Processed and saved IDCT for section_3859_modified.npy
# Processed and saved IDCT for section_3860_modified.npy
# Processed and saved IDCT for section_3861_modified.npy
# Processed and saved IDCT for section_3862_modified.npy
# Processed and saved IDCT for section_3863_modified.npy
# Processed and saved IDCT for section_3864_modified.npy
# Processed and saved IDCT for section_3865_modified.npy
# Processed and saved IDCT for section_3866_modified.npy
# Processed and saved IDCT for section_3867_modified.npy
# Processed and saved IDCT for section_3868_modified.npy
# Processed and saved IDCT for section_3869_modified.npy
# Processed and saved IDCT for section_3870_modified.npy
# Processed and saved IDCT for section_3871_modified.npy
# Processed and saved IDCT for section_3872_modified.npy
# Processed and saved IDCT for section_3873_modified.npy
# Processed and saved IDCT for section_3874_modified.npy
# Processed and saved IDCT for section_3875_modified.npy
# Processed and saved IDCT for section_3876_modified.npy
# Processed and saved IDCT for section_3877_modified.npy
# Processed and saved IDCT for section_3878_modified.npy
# Processed and saved IDCT for section_3879_modified.npy
# Processed and saved IDCT for section_3880_modified.npy
# Processed and saved IDCT for section_3881_modified.npy
# Processed and saved IDCT for section_3882_modified.npy
# Processed and saved IDCT for section_3883_modified.npy
# Processed and saved IDCT for section_3884_modified.npy
# Processed and saved IDCT for section_3885_modified.npy
# Processed and saved IDCT for section_3886_modified.npy
# Processed and saved IDCT for section_3887_modified.npy
# Processed and saved IDCT for section_3888_modified.npy
# Processed and saved IDCT for section_3889_modified.npy
# Processed and saved IDCT for section_3890_modified.npy
# Processed and saved IDCT for section_3891_modified.npy
# Processed and saved IDCT for section_3892_modified.npy
# Processed and saved IDCT for section_3893_modified.npy
# Processed and saved IDCT for section_3894_modified.npy
# Processed and saved IDCT for section_3895_modified.npy
# Processed and saved IDCT for section_3896_modified.npy
# Processed and saved IDCT for section_3897_modified.npy
# Processed and saved IDCT for section_3898_modified.npy
# Processed and saved IDCT for section_3899_modified.npy
# Processed and saved IDCT for section_3900_modified.npy
# Processed and saved IDCT for section_3901_modified.npy
# Processed and saved IDCT for section_3902_modified.npy
# Processed and saved IDCT for section_3903_modified.npy
# Processed and saved IDCT for section_3904_modified.npy
# Processed and saved IDCT for section_3905_modified.npy
# Processed and saved IDCT for section_3906_modified.npy
# Processed and saved IDCT for section_3907_modified.npy
# Processed and saved IDCT for section_3908_modified.npy
# Processed and saved IDCT for section_3909_modified.npy
# Processed and saved IDCT for section_3910_modified.npy
# Processed and saved IDCT for section_3911_modified.npy
# Processed and saved IDCT for section_3912_modified.npy
# Processed and saved IDCT for section_3913_modified.npy
# Processed and saved IDCT for section_3914_modified.npy
# Processed and saved IDCT for section_3915_modified.npy
# Processed and saved IDCT for section_3916_modified.npy
# Processed and saved IDCT for section_3917_modified.npy
# Processed and saved IDCT for section_3918_modified.npy
# Processed and saved IDCT for section_3919_modified.npy
# Processed and saved IDCT for section_3920_modified.npy
# Processed and saved IDCT for section_3921_modified.npy
# Processed and saved IDCT for section_3922_modified.npy
# Processed and saved IDCT for section_3923_modified.npy
# Processed and saved IDCT for section_3924_modified.npy
# Processed and saved IDCT for section_3925_modified.npy
# Processed and saved IDCT for section_3926_modified.npy
# Processed and saved IDCT for section_3927_modified.npy
# Processed and saved IDCT for section_3928_modified.npy
# Processed and saved IDCT for section_3929_modified.npy
# Processed and saved IDCT for section_3930_modified.npy
# Processed and saved IDCT for section_3931_modified.npy
# Processed and saved IDCT for section_3932_modified.npy
# Processed and saved IDCT for section_3933_modified.npy
# Processed and saved IDCT for section_3934_modified.npy
# Processed and saved IDCT for section_3935_modified.npy
# Processed and saved IDCT for section_3936_modified.npy
# Processed and saved IDCT for section_3937_modified.npy
# Processed and saved IDCT for section_3938_modified.npy
# Processed and saved IDCT for section_3939_modified.npy
# Processed and saved IDCT for section_3940_modified.npy
# Processed and saved IDCT for section_3941_modified.npy
# Processed and saved IDCT for section_3942_modified.npy
# Processed and saved IDCT for section_3943_modified.npy
# Processed and saved IDCT for section_3944_modified.npy
# Processed and saved IDCT for section_3945_modified.npy
# Processed and saved IDCT for section_3946_modified.npy
# Processed and saved IDCT for section_3947_modified.npy
# Processed and saved IDCT for section_3948_modified.npy
# Processed and saved IDCT for section_3949_modified.npy
# Processed and saved IDCT for section_3950_modified.npy
# Processed and saved IDCT for section_3951_modified.npy
# Processed and saved IDCT for section_3952_modified.npy
# Processed and saved IDCT for section_3953_modified.npy
# Processed and saved IDCT for section_3954_modified.npy
# Processed and saved IDCT for section_3955_modified.npy
# Processed and saved IDCT for section_3956_modified.npy
# Processed and saved IDCT for section_3957_modified.npy
# Processed and saved IDCT for section_3958_modified.npy
# Processed and saved IDCT for section_3959_modified.npy
# Processed and saved IDCT for section_3960_modified.npy
# Processed and saved IDCT for section_3961_modified.npy
# Processed and saved IDCT for section_3962_modified.npy
# Processed and saved IDCT for section_3963_modified.npy
# Processed and saved IDCT for section_3964_modified.npy
# Processed and saved IDCT for section_3965_modified.npy
# Processed and saved IDCT for section_3966_modified.npy
# Processed and saved IDCT for section_3967_modified.npy
# Processed and saved IDCT for section_3968_modified.npy
# Processed and saved IDCT for section_3969_modified.npy
# Processed and saved IDCT for section_3970_modified.npy
# Processed and saved IDCT for section_3971_modified.npy
# Processed and saved IDCT for section_3972_modified.npy
# Processed and saved IDCT for section_3973_modified.npy
# Processed and saved IDCT for section_3974_modified.npy
# Processed and saved IDCT for section_3975_modified.npy
# Processed and saved IDCT for section_3976_modified.npy
# Processed and saved IDCT for section_3977_modified.npy
# Processed and saved IDCT for section_3978_modified.npy
# Processed and saved IDCT for section_3979_modified.npy
# Processed and saved IDCT for section_3980_modified.npy
# Processed and saved IDCT for section_3981_modified.npy
# Processed and saved IDCT for section_3982_modified.npy
# Processed and saved IDCT for section_3983_modified.npy
# Processed and saved IDCT for section_3984_modified.npy
# Processed and saved IDCT for section_3985_modified.npy
# Processed and saved IDCT for section_3986_modified.npy
# Processed and saved IDCT for section_3987_modified.npy
# Processed and saved IDCT for section_3988_modified.npy
# Processed and saved IDCT for section_3989_modified.npy
# Processed and saved IDCT for section_3990_modified.npy
# Processed and saved IDCT for section_3991_modified.npy
# Processed and saved IDCT for section_3992_modified.npy
# Processed and saved IDCT for section_3993_modified.npy
# Processed and saved IDCT for section_3994_modified.npy
# Processed and saved IDCT for section_3995_modified.npy
# Processed and saved IDCT for section_3996_modified.npy
# Processed and saved IDCT for section_3997_modified.npy
# Processed and saved IDCT for section_3998_modified.npy
# Processed and saved IDCT for section_3999_modified.npy
# Processed and saved IDCT for section_4000_modified.npy
# Processed and saved IDCT for section_4001_modified.npy
# Processed and saved IDCT for section_4002_modified.npy
# Processed and saved IDCT for section_4003_modified.npy
# Processed and saved IDCT for section_4004_modified.npy
# Processed and saved IDCT for section_4005_modified.npy
# Processed and saved IDCT for section_4006_modified.npy
# Processed and saved IDCT for section_4007_modified.npy
# Processed and saved IDCT for section_4008_modified.npy
# Processed and saved IDCT for section_4009_modified.npy
# Processed and saved IDCT for section_4010_modified.npy
# Processed and saved IDCT for section_4011_modified.npy
# Processed and saved IDCT for section_4012_modified.npy
# Processed and saved IDCT for section_4013_modified.npy
# Processed and saved IDCT for section_4014_modified.npy
# Processed and saved IDCT for section_4015_modified.npy
# Processed and saved IDCT for section_4016_modified.npy
# Processed and saved IDCT for section_4017_modified.npy
# Processed and saved IDCT for section_4018_modified.npy
# Processed and saved IDCT for section_4019_modified.npy
# Processed and saved IDCT for section_4020_modified.npy
# Processed and saved IDCT for section_4021_modified.npy
# Processed and saved IDCT for section_4022_modified.npy
# Processed and saved IDCT for section_4023_modified.npy
# Processed and saved IDCT for section_4024_modified.npy
# Processed and saved IDCT for section_4025_modified.npy
# Processed and saved IDCT for section_4026_modified.npy
# Processed and saved IDCT for section_4027_modified.npy
# Processed and saved IDCT for section_4028_modified.npy
# Processed and saved IDCT for section_4029_modified.npy
# Processed and saved IDCT for section_4030_modified.npy
# Processed and saved IDCT for section_4031_modified.npy
# Processed and saved IDCT for section_4032_modified.npy
# Processed and saved IDCT for section_4033_modified.npy
# Processed and saved IDCT for section_4034_modified.npy
# Processed and saved IDCT for section_4035_modified.npy
# Processed and saved IDCT for section_4036_modified.npy
# Processed and saved IDCT for section_4037_modified.npy
# Processed and saved IDCT for section_4038_modified.npy
# Processed and saved IDCT for section_4039_modified.npy
# Processed and saved IDCT for section_4040_modified.npy
# Processed and saved IDCT for section_4041_modified.npy
# Processed and saved IDCT for section_4042_modified.npy
# Processed and saved IDCT for section_4043_modified.npy
# Processed and saved IDCT for section_4044_modified.npy
# Processed and saved IDCT for section_4045_modified.npy
# Processed and saved IDCT for section_4046_modified.npy
# Processed and saved IDCT for section_4047_modified.npy
# Processed and saved IDCT for section_4048_modified.npy
# Processed and saved IDCT for section_4049_modified.npy
# Processed and saved IDCT for section_4050_modified.npy
# Processed and saved IDCT for section_4051_modified.npy
# Processed and saved IDCT for section_4052_modified.npy
# Processed and saved IDCT for section_4053_modified.npy
# Processed and saved IDCT for section_4054_modified.npy
# Processed and saved IDCT for section_4055_modified.npy
# Processed and saved IDCT for section_4056_modified.npy
# Processed and saved IDCT for section_4057_modified.npy
# Processed and saved IDCT for section_4058_modified.npy
# Processed and saved IDCT for section_4059_modified.npy
# Processed and saved IDCT for section_4060_modified.npy
# Processed and saved IDCT for section_4061_modified.npy
# Processed and saved IDCT for section_4062_modified.npy
# Processed and saved IDCT for section_4063_modified.npy
# Processed and saved IDCT for section_4064_modified.npy
# Processed and saved IDCT for section_4065_modified.npy
# Processed and saved IDCT for section_4066_modified.npy
# Processed and saved IDCT for section_4067_modified.npy
# Processed and saved IDCT for section_4068_modified.npy
# Processed and saved IDCT for section_4069_modified.npy
# Processed and saved IDCT for section_4070_modified.npy
# Processed and saved IDCT for section_4071_modified.npy
# Processed and saved IDCT for section_4072_modified.npy
# Processed and saved IDCT for section_4073_modified.npy
# Processed and saved IDCT for section_4074_modified.npy
# Processed and saved IDCT for section_4075_modified.npy
# Processed and saved IDCT for section_4076_modified.npy
# Processed and saved IDCT for section_4077_modified.npy
# Processed and saved IDCT for section_4078_modified.npy
# Processed and saved IDCT for section_4079_modified.npy
# Processed and saved IDCT for section_4080_modified.npy
# Processed and saved IDCT for section_4081_modified.npy
# Processed and saved IDCT for section_4082_modified.npy
# Processed and saved IDCT for section_4083_modified.npy
# Processed and saved IDCT for section_4084_modified.npy
# Processed and saved IDCT for section_4085_modified.npy
# Processed and saved IDCT for section_4086_modified.npy
# Processed and saved IDCT for section_4087_modified.npy
# Processed and saved IDCT for section_4088_modified.npy
# Processed and saved IDCT for section_4089_modified.npy
# Processed and saved IDCT for section_4090_modified.npy
# Processed and saved IDCT for section_4091_modified.npy
# Processed and saved IDCT for section_4092_modified.npy
# Processed and saved IDCT for section_4093_modified.npy
# Processed and saved IDCT for section_4094_modified.npy
# Processed and saved IDCT for section_4095_modified.npy
# Processed and saved IDCT for section_4096_modified.npy
# All modified arrays have been processed.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Define the IDCT results directory and the size of the reconstructed large image
idct_dir = "/home/soujanya/Drive-F/IIT-KGP/Jupyter_Notebook/SP_Lab_2024_AM/idct_results/"
large_image_size = (512, 512)
small_section_size = (8, 8)
num_sections = large_image_size[0] // small_section_size[0]

# Initialize an empty array for the large reconstructed image
reconstructed_large_image = np.zeros(large_image_size, dtype=np.uint8)

# Load and place each 8x8 IDCT-reconstructed section in the correct position in the large image
for i in range(num_sections):
    for j in range(num_sections):
        section_filename = f"section_{i * num_sections + j + 1}_idct.npy"
        section_path = os.path.join(idct_dir, section_filename)
        section_array = np.load(section_path)
        
        # Place the 8x8 section in the appropriate location in the 512x512 image
        start_row = i * small_section_size[0]
        start_col = j * small_section_size[1]
        reconstructed_large_image[start_row:start_row + small_section_size[0],
                                  start_col:start_col + small_section_size[1]] = section_array

# Now, let's display the original large image and the reconstructed large image
original_large_image_path = "/home/soujanya/Downloads/standard_test_images/cameraman.tif"  
original_large_image = np.array(Image.open(original_large_image_path))

# Create a figure with 1 row and 2 columns
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Display the original large image in the first subplot
ax[0].imshow(original_large_image, cmap='gray')
ax[0].set_title('Original Image')
ax[0].axis('off')  # Hide axes

# Display the reconstructed large image in the second subplot
ax[1].imshow(reconstructed_large_image, cmap='gray')
ax[1].set_title('Reconstructed Image')
ax[1].axis('off')  # Hide axes

# Show the figure
plt.show()
